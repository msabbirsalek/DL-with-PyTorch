# %%
# Import Libraries
import torch
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import random_split
# %matplotlib inline
matplotlib.rcParams['figure.facecolor'] = '#ffffff'   # Background_color = white (fot matplotlib figures)

# %%
# Feedfoward neural network with 7 hidden layer
class Func_1_Model0(nn.Module):
    def __init__(self, in_size, dense_size_1, dense_size_2, dense_size_3, 
                 dense_size_4, dense_size_5, dense_size_6, dense_size_7, dense_size_8):
        super().__init__()
        # input layer
        self.in_layer = nn.Linear(in_size, in_size)
        # dense layer 1
        self.dense1 = nn.Linear(in_size, dense_size_1)
        # dense layer 2
        self.dense2 = nn.Linear(dense_size_1, dense_size_2)
        # dense layer 3
        self.dense3 = nn.Linear(dense_size_2, dense_size_3)
        # dense layer 4
        self.dense4 = nn.Linear(dense_size_3, dense_size_4)
        # dense layer 5
        self.dense5 = nn.Linear(dense_size_4, dense_size_5)
        # dense layer 6
        self.dense6 = nn.Linear(dense_size_5, dense_size_6)
        # dense layer 7
        self.dense7 = nn.Linear(dense_size_6, dense_size_7)
        # dense layer 8
        self.dense8 = nn.Linear(dense_size_7, dense_size_8)
        
    def forward(self, input_data):
        input_data = input_data.view(input_data.size(0), -1)
        
        # outputs using input layer
        out = self.in_layer(input_data)
        # activation function for input layer
        out = F.leaky_relu(out)
        
        # outputs using dense layer 1
        out = self.dense1(out)
        # activation function for dense layer 1
        out = F.leaky_relu(out)
        
        # outputs using dense layer 2
        out = self.dense2(out)
        # activation function for dense layer 2
        out = F.leaky_relu(out)
        
        # outputs using dense layer 3
        out = self.dense3(out)
        # activation function for dense layer 3
        out = F.leaky_relu(out)
        
        # outputs using dense layer 4
        out = self.dense4(out)
        # activation function for dense layer 4
        out = F.leaky_relu(out)
        
        # outputs using dense layer 5
        out = self.dense5(out)
        # activation function for dense layer 5
        out = F.leaky_relu(out)
        
        # outputs using dense layer 6
        out = self.dense6(out)
        # activation function for dense layer 6
        out = F.leaky_relu(out)
        
        # outputs using dense layer 7
        out = self.dense7(out)
        # activation function for dense layer 7
        out = F.leaky_relu(out)
        
        # predictions using dense layer 8
        out = self.dense8(out)
        return out
 
    def train(self, batch):
        x, y = batch 
        y = y.view(y.size(0), -1)
        out = self(x)                  # Generate predictions
        loss = F.mse_loss(out, y)      # Calculate loss
        return loss
    
    def validate(self, batch):
        x, y = batch 
        y = y.view(y.size(0), -1)
        out = self(x)                    # Generate predictions
        loss = F.mse_loss(out, y)        # Calculate loss
        return {'val_loss': loss}
        
    def validation_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        return {'val_loss': epoch_loss.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], val_loss: {:.4f}".format(epoch, result['val_loss']))

# %%
# Define NN layer sizes
input_size = 1
dense_size_1 = 5
dense_size_2 = 10
dense_size_3 = 10
dense_size_4 = 10
dense_size_5 = 10
dense_size_6 = 10
dense_size_7 = 5
dense_size_8 = 1

# %%
# Define NN model0

model0 = Func_1_Model0(input_size, dense_size_1, dense_size_2, dense_size_3,
                 dense_size_4, dense_size_5, dense_size_6, dense_size_7, dense_size_8).double()

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
count_parameters(model0)
# Out:
# 573

# %%
inputs = np.array([x/7001 for x in range(1,7001)], dtype='double')
array1 = np.sin(5*np.pi*inputs)
array2 = np.array(5*np.pi*inputs)
targets = np.array(array1/array2, dtype='double')

plt.plot(inputs,targets)
plt.xlabel('x')
plt.ylabel('sin(5*pi*x)/(5*pi*x)')
plt.show()

# %%
# Convert inputs and targets to tensors
inputs = torch.from_numpy(inputs)
targets = torch.from_numpy(targets)

# Define dataset
AllData = TensorDataset(inputs, targets)

# %%
# Separate datasets for training, validation, and testing
val_size = 1000
test_size = 1000
train_size = len(AllData) - val_size - test_size

train_ds, val_ds, test_ds = random_split(AllData, [train_size, val_size, test_size])

# Print length of the datasets
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (5000, 1000, 1000)

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

# %%
class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
batch_size = 500

train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=1, pin_memory=True)
val_dl = DataLoader(val_ds, batch_size, num_workers=1, pin_memory=True)

# %%
for x, _ in train_dl:
    print('x.shape:', x.shape)
    break
    
for y, _ in val_dl:
    print('y.shape:', y.shape)
    break
# Out:
# x.shape: torch.Size([500])
# y.shape: torch.Size([500])

# %% [markdown]
# # Training model0

# %%
def evaluate(model, val_dl):
    outputs = [model.validate(batch) for batch in val_dl]
    return model.validation_end(outputs)

def fit(epochs, lr, model, train_dl, val_dl, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr)
    for epoch in range(epochs):
        # Training Phase 
        for batch in train_dl:
            loss = model.train(batch)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_dl)
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
# Transfer dataset & model to GPU
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
to_device(model0, device)
# Out:
# Func_1_Model0(
#   (in_layer): Linear(in_features=1, out_features=1, bias=True)
#   (dense1): Linear(in_features=1, out_features=5, bias=True)
#   (dense2): Linear(in_features=5, out_features=10, bias=True)
#   (dense3): Linear(in_features=10, out_features=10, bias=True)
#   (dense4): Linear(in_features=10, out_features=10, bias=True)
#   (dense5): Linear(in_features=10, out_features=10, bias=True)
#   (dense6): Linear(in_features=10, out_features=10, bias=True)
#   (dense7): Linear(in_features=10, out_features=5, bias=True)
#   (dense8): Linear(in_features=5, out_features=1, bias=True)
# )

# %%
history = [evaluate(model0, val_dl)]
history
# Out:
# [{'val_loss': 0.11563688489206683}]

# %%
history += fit(20000, 0.001, model0, train_dl, val_dl)
# Out:
# Epoch [0], val_loss: 0.1138
# Epoch [1], val_loss: 0.1120
# Epoch [2], val_loss: 0.1104
# Epoch [3], val_loss: 0.1089
# Epoch [4], val_loss: 0.1075
# Epoch [5], val_loss: 0.1062
# Epoch [6], val_loss: 0.1049
# Epoch [7], val_loss: 0.1038
# Epoch [8], val_loss: 0.1028
# Epoch [9], val_loss: 0.1018
# Epoch [10], val_loss: 0.1009
# Epoch [11], val_loss: 0.1000
# Epoch [12], val_loss: 0.0992
# Epoch [13], val_loss: 0.0985
# Epoch [14], val_loss: 0.0978
# Epoch [15], val_loss: 0.0971
# Epoch [16], val_loss: 0.0966
# Epoch [17], val_loss: 0.0960
# Epoch [18], val_loss: 0.0955
# Epoch [19], val_loss: 0.0950
# Epoch [20], val_loss: 0.0946
# Epoch [21], val_loss: 0.0941
# Epoch [22], val_loss: 0.0937
# Epoch [23], val_loss: 0.0934
# Epoch [24], val_loss: 0.0931
# Epoch [25], val_loss: 0.0927
# Epoch [26], val_loss: 0.0925
# Epoch [27], val_loss: 0.0922
# Epoch [28], val_loss: 0.0919
# Epoch [29], val_loss: 0.0917
# Epoch [30], val_loss: 0.0915
# Epoch [31], val_loss: 0.0913
# Epoch [32], val_loss: 0.0911
# Epoch [33], val_loss: 0.0909
# Epoch [34], val_loss: 0.0908
# Epoch [35], val_loss: 0.0906
# Epoch [36], val_loss: 0.0905
# Epoch [37], val_loss: 0.0903
# Epoch [38], val_loss: 0.0902
# Epoch [39], val_loss: 0.0901
# Epoch [40], val_loss: 0.0900
# Epoch [41], val_loss: 0.0899
# Epoch [42], val_loss: 0.0898
# Epoch [43], val_loss: 0.0897
# Epoch [44], val_loss: 0.0897
# Epoch [45], val_loss: 0.0896
# Epoch [46], val_loss: 0.0895
# Epoch [47], val_loss: 0.0895
# Epoch [48], val_loss: 0.0894
# Epoch [49], val_loss: 0.0894
# Epoch [50], val_loss: 0.0893
# Epoch [51], val_loss: 0.0893
# Epoch [52], val_loss: 0.0892
# Epoch [53], val_loss: 0.0892
# Epoch [54], val_loss: 0.0892
# Epoch [55], val_loss: 0.0891
# Epoch [56], val_loss: 0.0891
# Epoch [57], val_loss: 0.0891
# Epoch [58], val_loss: 0.0891
# Epoch [59], val_loss: 0.0890
# Epoch [60], val_loss: 0.0890
# Epoch [61], val_loss: 0.0890
# Epoch [62], val_loss: 0.0890
# Epoch [63], val_loss: 0.0890
# Epoch [64], val_loss: 0.0889
# Epoch [65], val_loss: 0.0889
# Epoch [66], val_loss: 0.0889
# Epoch [67], val_loss: 0.0889
# Epoch [68], val_loss: 0.0889
# Epoch [69], val_loss: 0.0889
# Epoch [70], val_loss: 0.0889
# Epoch [71], val_loss: 0.0889
# Epoch [72], val_loss: 0.0889
# Epoch [73], val_loss: 0.0889
# Epoch [74], val_loss: 0.0889
# Epoch [75], val_loss: 0.0889
# Epoch [76], val_loss: 0.0889
# Epoch [77], val_loss: 0.0889
# Epoch [78], val_loss: 0.0889
# Epoch [79], val_loss: 0.0888
# Epoch [80], val_loss: 0.0888
# Epoch [81], val_loss: 0.0888
# Epoch [82], val_loss: 0.0888
# Epoch [83], val_loss: 0.0888
# Epoch [84], val_loss: 0.0888
# Epoch [85], val_loss: 0.0888
# Epoch [86], val_loss: 0.0888
# Epoch [87], val_loss: 0.0888
# Epoch [88], val_loss: 0.0888
# Epoch [89], val_loss: 0.0888
# Epoch [90], val_loss: 0.0888
# Epoch [91], val_loss: 0.0888
# Epoch [92], val_loss: 0.0888
# Epoch [93], val_loss: 0.0888
# Epoch [94], val_loss: 0.0888
# Epoch [95], val_loss: 0.0888
# Epoch [96], val_loss: 0.0888
# Epoch [97], val_loss: 0.0888
# Epoch [98], val_loss: 0.0888
# Epoch [99], val_loss: 0.0888
# Epoch [100], val_loss: 0.0889
# Epoch [101], val_loss: 0.0889
# Epoch [102], val_loss: 0.0889
# Epoch [103], val_loss: 0.0889
# Epoch [104], val_loss: 0.0889
# Epoch [105], val_loss: 0.0889
# Epoch [106], val_loss: 0.0889
# Epoch [107], val_loss: 0.0889
# Epoch [108], val_loss: 0.0889
# Epoch [109], val_loss: 0.0889
# Epoch [110], val_loss: 0.0889
# Epoch [111], val_loss: 0.0889
# Epoch [112], val_loss: 0.0889
# Epoch [113], val_loss: 0.0889
# Epoch [114], val_loss: 0.0889
# Epoch [115], val_loss: 0.0889
# Epoch [116], val_loss: 0.0889
# Epoch [117], val_loss: 0.0889
# Epoch [118], val_loss: 0.0889
# Epoch [119], val_loss: 0.0889
# Epoch [120], val_loss: 0.0889
# Epoch [121], val_loss: 0.0889
# Epoch [122], val_loss: 0.0889
# Epoch [123], val_loss: 0.0889
# Epoch [124], val_loss: 0.0889
# Epoch [125], val_loss: 0.0889
# Epoch [126], val_loss: 0.0889
# Epoch [127], val_loss: 0.0889
# Epoch [128], val_loss: 0.0889
# Epoch [129], val_loss: 0.0889
# Epoch [130], val_loss: 0.0889
# Epoch [131], val_loss: 0.0889
# Epoch [132], val_loss: 0.0889
# Epoch [133], val_loss: 0.0889
# Epoch [134], val_loss: 0.0889
# Epoch [135], val_loss: 0.0889
# Epoch [136], val_loss: 0.0889
# Epoch [137], val_loss: 0.0889
# Epoch [138], val_loss: 0.0889
# Epoch [139], val_loss: 0.0889
# Epoch [140], val_loss: 0.0889
# Epoch [141], val_loss: 0.0889
# Epoch [142], val_loss: 0.0889
# Epoch [143], val_loss: 0.0889
# Epoch [144], val_loss: 0.0889
# Epoch [145], val_loss: 0.0889
# Epoch [146], val_loss: 0.0889
# Epoch [147], val_loss: 0.0889
# Epoch [148], val_loss: 0.0889
# Epoch [149], val_loss: 0.0889
# Epoch [150], val_loss: 0.0889
# Epoch [151], val_loss: 0.0889
# Epoch [152], val_loss: 0.0889
# Epoch [153], val_loss: 0.0889
# Epoch [154], val_loss: 0.0889
# Epoch [155], val_loss: 0.0889
# Epoch [156], val_loss: 0.0889
# Epoch [157], val_loss: 0.0889
# Epoch [158], val_loss: 0.0889
# Epoch [159], val_loss: 0.0889
# Epoch [160], val_loss: 0.0889
# Epoch [161], val_loss: 0.0889
# Epoch [162], val_loss: 0.0889
# Epoch [163], val_loss: 0.0889
# Epoch [164], val_loss: 0.0889
# Epoch [165], val_loss: 0.0889
# Epoch [166], val_loss: 0.0889
# Epoch [167], val_loss: 0.0889
# Epoch [168], val_loss: 0.0889
# Epoch [169], val_loss: 0.0889
# Epoch [170], val_loss: 0.0889
# Epoch [171], val_loss: 0.0889
# Epoch [172], val_loss: 0.0889
# Epoch [173], val_loss: 0.0889
# Epoch [174], val_loss: 0.0889
# Epoch [175], val_loss: 0.0889
# Epoch [176], val_loss: 0.0889
# Epoch [177], val_loss: 0.0889
# Epoch [178], val_loss: 0.0889
# Epoch [179], val_loss: 0.0889
# Epoch [180], val_loss: 0.0889
# Epoch [181], val_loss: 0.0889
# Epoch [182], val_loss: 0.0889
# Epoch [183], val_loss: 0.0889
# Epoch [184], val_loss: 0.0889
# Epoch [185], val_loss: 0.0889
# Epoch [186], val_loss: 0.0889
# Epoch [187], val_loss: 0.0889
# Epoch [188], val_loss: 0.0889
# Epoch [189], val_loss: 0.0889
# Epoch [190], val_loss: 0.0889
# Epoch [191], val_loss: 0.0889
# Epoch [192], val_loss: 0.0889
# Epoch [193], val_loss: 0.0889
# Epoch [194], val_loss: 0.0889
# Epoch [195], val_loss: 0.0889
# Epoch [196], val_loss: 0.0889
# Epoch [197], val_loss: 0.0889
# Epoch [198], val_loss: 0.0889
# Epoch [199], val_loss: 0.0889
# Epoch [200], val_loss: 0.0889
# Epoch [201], val_loss: 0.0889
# Epoch [202], val_loss: 0.0889
# Epoch [203], val_loss: 0.0889
# Epoch [204], val_loss: 0.0889
# Epoch [205], val_loss: 0.0889
# Epoch [206], val_loss: 0.0889
# Epoch [207], val_loss: 0.0889
# Epoch [208], val_loss: 0.0889
# Epoch [209], val_loss: 0.0889
# Epoch [210], val_loss: 0.0889
# Epoch [211], val_loss: 0.0890
# Epoch [212], val_loss: 0.0890
# Epoch [213], val_loss: 0.0890
# Epoch [214], val_loss: 0.0890
# Epoch [215], val_loss: 0.0890
# Epoch [216], val_loss: 0.0890
# Epoch [217], val_loss: 0.0890
# Epoch [218], val_loss: 0.0890
# Epoch [219], val_loss: 0.0890
# Epoch [220], val_loss: 0.0890
# Epoch [221], val_loss: 0.0890
# Epoch [222], val_loss: 0.0890
# Epoch [223], val_loss: 0.0890
# Epoch [224], val_loss: 0.0890
# Epoch [225], val_loss: 0.0890
# Epoch [226], val_loss: 0.0890
# Epoch [227], val_loss: 0.0890
# Epoch [228], val_loss: 0.0890
# Epoch [229], val_loss: 0.0890
# Epoch [230], val_loss: 0.0890
# Epoch [231], val_loss: 0.0890
# Epoch [232], val_loss: 0.0890
# Epoch [233], val_loss: 0.0890
# Epoch [234], val_loss: 0.0890
# Epoch [235], val_loss: 0.0890
# Epoch [236], val_loss: 0.0890
# Epoch [237], val_loss: 0.0890
# Epoch [238], val_loss: 0.0890
# Epoch [239], val_loss: 0.0890
# Epoch [240], val_loss: 0.0890
# Epoch [241], val_loss: 0.0890
# Epoch [242], val_loss: 0.0890
# Epoch [243], val_loss: 0.0890
# Epoch [244], val_loss: 0.0890
# Epoch [245], val_loss: 0.0890
# Epoch [246], val_loss: 0.0890
# Epoch [247], val_loss: 0.0890
# Epoch [248], val_loss: 0.0890
# Epoch [249], val_loss: 0.0890
# Epoch [250], val_loss: 0.0890
# Epoch [251], val_loss: 0.0890
# Epoch [252], val_loss: 0.0890
# Epoch [253], val_loss: 0.0890
# Epoch [254], val_loss: 0.0890
# Epoch [255], val_loss: 0.0890
# Epoch [256], val_loss: 0.0890
# Epoch [257], val_loss: 0.0890
# Epoch [258], val_loss: 0.0890
# Epoch [259], val_loss: 0.0890
# Epoch [260], val_loss: 0.0890
# Epoch [261], val_loss: 0.0890
# Epoch [262], val_loss: 0.0890
# Epoch [263], val_loss: 0.0890
# Epoch [264], val_loss: 0.0890
# Epoch [265], val_loss: 0.0890
# Epoch [266], val_loss: 0.0890
# Epoch [267], val_loss: 0.0890
# Epoch [268], val_loss: 0.0890
# Epoch [269], val_loss: 0.0890
# Epoch [270], val_loss: 0.0890
# Epoch [271], val_loss: 0.0890
# Epoch [272], val_loss: 0.0890
# Epoch [273], val_loss: 0.0890
# Epoch [274], val_loss: 0.0890
# Epoch [275], val_loss: 0.0890
# Epoch [276], val_loss: 0.0890
# Epoch [277], val_loss: 0.0890
# Epoch [278], val_loss: 0.0890
# Epoch [279], val_loss: 0.0890
# Epoch [280], val_loss: 0.0890
# Epoch [281], val_loss: 0.0890
# Epoch [282], val_loss: 0.0890
# Epoch [283], val_loss: 0.0890
# Epoch [284], val_loss: 0.0890
# Epoch [285], val_loss: 0.0890
# Epoch [286], val_loss: 0.0890
# Epoch [287], val_loss: 0.0890
# Epoch [288], val_loss: 0.0890
# Epoch [289], val_loss: 0.0890
# Epoch [290], val_loss: 0.0890
# Epoch [291], val_loss: 0.0890
# Epoch [292], val_loss: 0.0890
# Epoch [293], val_loss: 0.0890
# Epoch [294], val_loss: 0.0890
# Epoch [295], val_loss: 0.0890
# Epoch [296], val_loss: 0.0890
# Epoch [297], val_loss: 0.0890
# Epoch [298], val_loss: 0.0890
# Epoch [299], val_loss: 0.0890
# Epoch [300], val_loss: 0.0890
# Epoch [301], val_loss: 0.0890
# Epoch [302], val_loss: 0.0890
# Epoch [303], val_loss: 0.0890
# Epoch [304], val_loss: 0.0890
# Epoch [305], val_loss: 0.0890
# Epoch [306], val_loss: 0.0890
# Epoch [307], val_loss: 0.0890
# Epoch [308], val_loss: 0.0890
# Epoch [309], val_loss: 0.0890
# Epoch [310], val_loss: 0.0890
# Epoch [311], val_loss: 0.0890
# Epoch [312], val_loss: 0.0890
# Epoch [313], val_loss: 0.0890
# Epoch [314], val_loss: 0.0890
# Epoch [315], val_loss: 0.0890
# Epoch [316], val_loss: 0.0890
# Epoch [317], val_loss: 0.0890
# Epoch [318], val_loss: 0.0890
# Epoch [319], val_loss: 0.0890
# Epoch [320], val_loss: 0.0890
# Epoch [321], val_loss: 0.0890
# Epoch [322], val_loss: 0.0890
# Epoch [323], val_loss: 0.0890
# Epoch [324], val_loss: 0.0890
# Epoch [325], val_loss: 0.0890
# Epoch [326], val_loss: 0.0890
# Epoch [327], val_loss: 0.0890
# Epoch [328], val_loss: 0.0890
# Epoch [329], val_loss: 0.0890
# Epoch [330], val_loss: 0.0890
# Epoch [331], val_loss: 0.0890
# Epoch [332], val_loss: 0.0890
# Epoch [333], val_loss: 0.0890
# Epoch [334], val_loss: 0.0890
# Epoch [335], val_loss: 0.0890
# Epoch [336], val_loss: 0.0890
# Epoch [337], val_loss: 0.0890
# Epoch [338], val_loss: 0.0890
# Epoch [339], val_loss: 0.0890
# Epoch [340], val_loss: 0.0890
# Epoch [341], val_loss: 0.0890
# Epoch [342], val_loss: 0.0890
# Epoch [343], val_loss: 0.0890
# Epoch [344], val_loss: 0.0890
# Epoch [345], val_loss: 0.0890
# Epoch [346], val_loss: 0.0890
# Epoch [347], val_loss: 0.0890
# Epoch [348], val_loss: 0.0890
# Epoch [349], val_loss: 0.0890
# Epoch [350], val_loss: 0.0890
# Epoch [351], val_loss: 0.0890
# Epoch [352], val_loss: 0.0890
# Epoch [353], val_loss: 0.0890
# Epoch [354], val_loss: 0.0890
# Epoch [355], val_loss: 0.0890
# Epoch [356], val_loss: 0.0890
# Epoch [357], val_loss: 0.0890
# Epoch [358], val_loss: 0.0890
# Epoch [359], val_loss: 0.0890
# Epoch [360], val_loss: 0.0890
# Epoch [361], val_loss: 0.0890
# Epoch [362], val_loss: 0.0890
# Epoch [363], val_loss: 0.0890
# Epoch [364], val_loss: 0.0890
# Epoch [365], val_loss: 0.0890
# Epoch [366], val_loss: 0.0890
# Epoch [367], val_loss: 0.0890
# Epoch [368], val_loss: 0.0890
# Epoch [369], val_loss: 0.0890
# Epoch [370], val_loss: 0.0890
# Epoch [371], val_loss: 0.0890
# Epoch [372], val_loss: 0.0890
# Epoch [373], val_loss: 0.0890
# Epoch [374], val_loss: 0.0890
# Epoch [375], val_loss: 0.0890
# Epoch [376], val_loss: 0.0890
# Epoch [377], val_loss: 0.0890
# Epoch [378], val_loss: 0.0890
# Epoch [379], val_loss: 0.0890
# Epoch [380], val_loss: 0.0890
# Epoch [381], val_loss: 0.0890
# Epoch [382], val_loss: 0.0890
# Epoch [383], val_loss: 0.0890
# Epoch [384], val_loss: 0.0890
# Epoch [385], val_loss: 0.0890
# Epoch [386], val_loss: 0.0890
# Epoch [387], val_loss: 0.0890
# Epoch [388], val_loss: 0.0890
# Epoch [389], val_loss: 0.0890
# Epoch [390], val_loss: 0.0890
# Epoch [391], val_loss: 0.0890
# Epoch [392], val_loss: 0.0890
# Epoch [393], val_loss: 0.0890
# Epoch [394], val_loss: 0.0890
# Epoch [395], val_loss: 0.0890
# Epoch [396], val_loss: 0.0890
# Epoch [397], val_loss: 0.0890
# Epoch [398], val_loss: 0.0890
# Epoch [399], val_loss: 0.0890
# Epoch [400], val_loss: 0.0890
# Epoch [401], val_loss: 0.0890
# Epoch [402], val_loss: 0.0890
# Epoch [403], val_loss: 0.0890
# Epoch [404], val_loss: 0.0890
# Epoch [405], val_loss: 0.0890
# Epoch [406], val_loss: 0.0890
# Epoch [407], val_loss: 0.0890
# Epoch [408], val_loss: 0.0890
# Epoch [409], val_loss: 0.0890
# Epoch [410], val_loss: 0.0890
# Epoch [411], val_loss: 0.0890
# Epoch [412], val_loss: 0.0890
# Epoch [413], val_loss: 0.0890
# Epoch [414], val_loss: 0.0890
# Epoch [415], val_loss: 0.0890
# Epoch [416], val_loss: 0.0890
# Epoch [417], val_loss: 0.0890
# Epoch [418], val_loss: 0.0890
# Epoch [419], val_loss: 0.0890
# Epoch [420], val_loss: 0.0890
# Epoch [421], val_loss: 0.0890
# Epoch [422], val_loss: 0.0890
# Epoch [423], val_loss: 0.0890
# Epoch [424], val_loss: 0.0890
# Epoch [425], val_loss: 0.0890
# Epoch [426], val_loss: 0.0890
# Epoch [427], val_loss: 0.0890
# Epoch [428], val_loss: 0.0890
# Epoch [429], val_loss: 0.0890
# Epoch [430], val_loss: 0.0890
# Epoch [431], val_loss: 0.0890
# Epoch [432], val_loss: 0.0890
# Epoch [433], val_loss: 0.0890
# Epoch [434], val_loss: 0.0890
# Epoch [435], val_loss: 0.0890
# Epoch [436], val_loss: 0.0890
# Epoch [437], val_loss: 0.0890
# Epoch [438], val_loss: 0.0890
# Epoch [439], val_loss: 0.0890
# Epoch [440], val_loss: 0.0890
# Epoch [441], val_loss: 0.0890
# Epoch [442], val_loss: 0.0890
# Epoch [443], val_loss: 0.0890
# Epoch [444], val_loss: 0.0890
# Epoch [445], val_loss: 0.0890
# Epoch [446], val_loss: 0.0890
# Epoch [447], val_loss: 0.0890
# Epoch [448], val_loss: 0.0890
# Epoch [449], val_loss: 0.0890
# Epoch [450], val_loss: 0.0890
# Epoch [451], val_loss: 0.0890
# Epoch [452], val_loss: 0.0890
# Epoch [453], val_loss: 0.0890
# Epoch [454], val_loss: 0.0890
# Epoch [455], val_loss: 0.0890
# Epoch [456], val_loss: 0.0890
# Epoch [457], val_loss: 0.0890
# Epoch [458], val_loss: 0.0890
# Epoch [459], val_loss: 0.0890
# Epoch [460], val_loss: 0.0890
# Epoch [461], val_loss: 0.0890
# Epoch [462], val_loss: 0.0890
# Epoch [463], val_loss: 0.0890
# Epoch [464], val_loss: 0.0890
# Epoch [465], val_loss: 0.0890
# Epoch [466], val_loss: 0.0890
# Epoch [467], val_loss: 0.0890
# Epoch [468], val_loss: 0.0890
# Epoch [469], val_loss: 0.0890
# Epoch [470], val_loss: 0.0890
# Epoch [471], val_loss: 0.0890
# Epoch [472], val_loss: 0.0890
# Epoch [473], val_loss: 0.0890
# Epoch [474], val_loss: 0.0890
# Epoch [475], val_loss: 0.0890
# Epoch [476], val_loss: 0.0890
# Epoch [477], val_loss: 0.0890
# Epoch [478], val_loss: 0.0890
# Epoch [479], val_loss: 0.0890
# Epoch [480], val_loss: 0.0890
# Epoch [481], val_loss: 0.0890
# Epoch [482], val_loss: 0.0890
# Epoch [483], val_loss: 0.0890
# Epoch [484], val_loss: 0.0890
# Epoch [485], val_loss: 0.0890
# Epoch [486], val_loss: 0.0890
# Epoch [487], val_loss: 0.0890
# Epoch [488], val_loss: 0.0890
# Epoch [489], val_loss: 0.0890
# Epoch [490], val_loss: 0.0890
# Epoch [491], val_loss: 0.0890
# Epoch [492], val_loss: 0.0890
# Epoch [493], val_loss: 0.0890
# Epoch [494], val_loss: 0.0890
# Epoch [495], val_loss: 0.0890
# Epoch [496], val_loss: 0.0890
# Epoch [497], val_loss: 0.0890
# Epoch [498], val_loss: 0.0890
# Epoch [499], val_loss: 0.0890
# Epoch [500], val_loss: 0.0890
# Epoch [501], val_loss: 0.0890
# Epoch [502], val_loss: 0.0890
# Epoch [503], val_loss: 0.0890
# Epoch [504], val_loss: 0.0890
# Epoch [505], val_loss: 0.0890
# Epoch [506], val_loss: 0.0890
# Epoch [507], val_loss: 0.0890
# Epoch [508], val_loss: 0.0890
# Epoch [509], val_loss: 0.0890
# Epoch [510], val_loss: 0.0890
# Epoch [511], val_loss: 0.0890
# Epoch [512], val_loss: 0.0890
# Epoch [513], val_loss: 0.0890
# Epoch [514], val_loss: 0.0890
# Epoch [515], val_loss: 0.0890
# Epoch [516], val_loss: 0.0890
# Epoch [517], val_loss: 0.0890
# Epoch [518], val_loss: 0.0890
# Epoch [519], val_loss: 0.0890
# Epoch [520], val_loss: 0.0890
# Epoch [521], val_loss: 0.0890
# Epoch [522], val_loss: 0.0890
# Epoch [523], val_loss: 0.0890
# Epoch [524], val_loss: 0.0890
# Epoch [525], val_loss: 0.0890
# Epoch [526], val_loss: 0.0890
# Epoch [527], val_loss: 0.0890
# Epoch [528], val_loss: 0.0890
# Epoch [529], val_loss: 0.0890
# Epoch [530], val_loss: 0.0890
# Epoch [531], val_loss: 0.0890
# Epoch [532], val_loss: 0.0890
# Epoch [533], val_loss: 0.0890
# Epoch [534], val_loss: 0.0890
# Epoch [535], val_loss: 0.0890
# Epoch [536], val_loss: 0.0890
# Epoch [537], val_loss: 0.0890
# Epoch [538], val_loss: 0.0890
# Epoch [539], val_loss: 0.0890
# Epoch [540], val_loss: 0.0890
# Epoch [541], val_loss: 0.0890
# Epoch [542], val_loss: 0.0890
# Epoch [543], val_loss: 0.0890
# Epoch [544], val_loss: 0.0890
# Epoch [545], val_loss: 0.0890
# Epoch [546], val_loss: 0.0890
# Epoch [547], val_loss: 0.0890
# Epoch [548], val_loss: 0.0890
# Epoch [549], val_loss: 0.0890
# Epoch [550], val_loss: 0.0890
# Epoch [551], val_loss: 0.0890
# Epoch [552], val_loss: 0.0890
# Epoch [553], val_loss: 0.0890
# Epoch [554], val_loss: 0.0890
# Epoch [555], val_loss: 0.0890
# Epoch [556], val_loss: 0.0890
# Epoch [557], val_loss: 0.0890
# Epoch [558], val_loss: 0.0890
# Epoch [559], val_loss: 0.0890
# Epoch [560], val_loss: 0.0890
# Epoch [561], val_loss: 0.0890
# Epoch [562], val_loss: 0.0890
# Epoch [563], val_loss: 0.0890
# Epoch [564], val_loss: 0.0890
# Epoch [565], val_loss: 0.0890
# Epoch [566], val_loss: 0.0890
# Epoch [567], val_loss: 0.0890
# Epoch [568], val_loss: 0.0890
# Epoch [569], val_loss: 0.0890
# Epoch [570], val_loss: 0.0890
# Epoch [571], val_loss: 0.0890
# Epoch [572], val_loss: 0.0890
# Epoch [573], val_loss: 0.0890
# Epoch [574], val_loss: 0.0890
# Epoch [575], val_loss: 0.0890
# Epoch [576], val_loss: 0.0890
# Epoch [577], val_loss: 0.0890
# Epoch [578], val_loss: 0.0890
# Epoch [579], val_loss: 0.0890
# Epoch [580], val_loss: 0.0890
# Epoch [581], val_loss: 0.0890
# Epoch [582], val_loss: 0.0890
# Epoch [583], val_loss: 0.0890
# Epoch [584], val_loss: 0.0890
# Epoch [585], val_loss: 0.0890
# Epoch [586], val_loss: 0.0890
# Epoch [587], val_loss: 0.0890
# Epoch [588], val_loss: 0.0890
# Epoch [589], val_loss: 0.0890
# Epoch [590], val_loss: 0.0890
# Epoch [591], val_loss: 0.0890
# Epoch [592], val_loss: 0.0890
# Epoch [593], val_loss: 0.0890
# Epoch [594], val_loss: 0.0890
# Epoch [595], val_loss: 0.0890
# Epoch [596], val_loss: 0.0890
# Epoch [597], val_loss: 0.0890
# Epoch [598], val_loss: 0.0890
# Epoch [599], val_loss: 0.0890
# Epoch [600], val_loss: 0.0890
# Epoch [601], val_loss: 0.0890
# Epoch [602], val_loss: 0.0890
# Epoch [603], val_loss: 0.0890
# Epoch [604], val_loss: 0.0890
# Epoch [605], val_loss: 0.0890
# Epoch [606], val_loss: 0.0890
# Epoch [607], val_loss: 0.0890
# Epoch [608], val_loss: 0.0890
# Epoch [609], val_loss: 0.0890
# Epoch [610], val_loss: 0.0890
# Epoch [611], val_loss: 0.0890
# Epoch [612], val_loss: 0.0890
# Epoch [613], val_loss: 0.0890
# Epoch [614], val_loss: 0.0890
# Epoch [615], val_loss: 0.0890
# Epoch [616], val_loss: 0.0890
# Epoch [617], val_loss: 0.0890
# Epoch [618], val_loss: 0.0890
# Epoch [619], val_loss: 0.0890
# Epoch [620], val_loss: 0.0890
# Epoch [621], val_loss: 0.0890
# Epoch [622], val_loss: 0.0890
# Epoch [623], val_loss: 0.0890
# Epoch [624], val_loss: 0.0890
# Epoch [625], val_loss: 0.0890
# Epoch [626], val_loss: 0.0890
# Epoch [627], val_loss: 0.0890
# Epoch [628], val_loss: 0.0890
# Epoch [629], val_loss: 0.0890
# Epoch [630], val_loss: 0.0890
# Epoch [631], val_loss: 0.0890
# Epoch [632], val_loss: 0.0890
# Epoch [633], val_loss: 0.0890
# Epoch [634], val_loss: 0.0890
# Epoch [635], val_loss: 0.0890
# Epoch [636], val_loss: 0.0890
# Epoch [637], val_loss: 0.0890
# Epoch [638], val_loss: 0.0890
# Epoch [639], val_loss: 0.0890
# Epoch [640], val_loss: 0.0890
# Epoch [641], val_loss: 0.0890
# Epoch [642], val_loss: 0.0890
# Epoch [643], val_loss: 0.0890
# Epoch [644], val_loss: 0.0890
# Epoch [645], val_loss: 0.0890
# Epoch [646], val_loss: 0.0890
# Epoch [647], val_loss: 0.0890
# Epoch [648], val_loss: 0.0890
# Epoch [649], val_loss: 0.0890
# Epoch [650], val_loss: 0.0890
# Epoch [651], val_loss: 0.0890
# Epoch [652], val_loss: 0.0890
# Epoch [653], val_loss: 0.0890
# Epoch [654], val_loss: 0.0890
# Epoch [655], val_loss: 0.0890
# Epoch [656], val_loss: 0.0890
# Epoch [657], val_loss: 0.0890
# Epoch [658], val_loss: 0.0890
# Epoch [659], val_loss: 0.0890
# Epoch [660], val_loss: 0.0890
# Epoch [661], val_loss: 0.0890
# Epoch [662], val_loss: 0.0890
# Epoch [663], val_loss: 0.0890
# Epoch [664], val_loss: 0.0890
# Epoch [665], val_loss: 0.0890
# Epoch [666], val_loss: 0.0890
# Epoch [667], val_loss: 0.0890
# Epoch [668], val_loss: 0.0890
# Epoch [669], val_loss: 0.0890
# Epoch [670], val_loss: 0.0890
# Epoch [671], val_loss: 0.0890
# Epoch [672], val_loss: 0.0890
# Epoch [673], val_loss: 0.0890
# Epoch [674], val_loss: 0.0890
# Epoch [675], val_loss: 0.0890
# Epoch [676], val_loss: 0.0890
# Epoch [677], val_loss: 0.0890
# Epoch [678], val_loss: 0.0890
# Epoch [679], val_loss: 0.0890
# Epoch [680], val_loss: 0.0890
# Epoch [681], val_loss: 0.0890
# Epoch [682], val_loss: 0.0890
# Epoch [683], val_loss: 0.0890
# Epoch [684], val_loss: 0.0890
# Epoch [685], val_loss: 0.0890
# Epoch [686], val_loss: 0.0890
# Epoch [687], val_loss: 0.0890
# Epoch [688], val_loss: 0.0890
# Epoch [689], val_loss: 0.0890
# Epoch [690], val_loss: 0.0890
# Epoch [691], val_loss: 0.0890
# Epoch [692], val_loss: 0.0890
# Epoch [693], val_loss: 0.0890
# Epoch [694], val_loss: 0.0890
# Epoch [695], val_loss: 0.0890
# Epoch [696], val_loss: 0.0890
# Epoch [697], val_loss: 0.0890
# Epoch [698], val_loss: 0.0890
# Epoch [699], val_loss: 0.0890
# Epoch [700], val_loss: 0.0890
# Epoch [701], val_loss: 0.0890
# Epoch [702], val_loss: 0.0890
# Epoch [703], val_loss: 0.0890
# Epoch [704], val_loss: 0.0890
# Epoch [705], val_loss: 0.0890
# Epoch [706], val_loss: 0.0890
# Epoch [707], val_loss: 0.0890
# Epoch [708], val_loss: 0.0890
# Epoch [709], val_loss: 0.0890
# Epoch [710], val_loss: 0.0890
# Epoch [711], val_loss: 0.0890
# Epoch [712], val_loss: 0.0890
# Epoch [713], val_loss: 0.0890
# Epoch [714], val_loss: 0.0890
# Epoch [715], val_loss: 0.0890
# Epoch [716], val_loss: 0.0890
# Epoch [717], val_loss: 0.0890
# Epoch [718], val_loss: 0.0890
# Epoch [719], val_loss: 0.0890
# Epoch [720], val_loss: 0.0890
# Epoch [721], val_loss: 0.0890
# Epoch [722], val_loss: 0.0890
# Epoch [723], val_loss: 0.0890
# Epoch [724], val_loss: 0.0890
# Epoch [725], val_loss: 0.0890
# Epoch [726], val_loss: 0.0890
# Epoch [727], val_loss: 0.0890
# Epoch [728], val_loss: 0.0890
# Epoch [729], val_loss: 0.0890
# Epoch [730], val_loss: 0.0890
# Epoch [731], val_loss: 0.0890
# Epoch [732], val_loss: 0.0890
# Epoch [733], val_loss: 0.0890
# Epoch [734], val_loss: 0.0890
# Epoch [735], val_loss: 0.0890
# Epoch [736], val_loss: 0.0890
# Epoch [737], val_loss: 0.0890
# Epoch [738], val_loss: 0.0890
# Epoch [739], val_loss: 0.0890
# Epoch [740], val_loss: 0.0890
# Epoch [741], val_loss: 0.0890
# Epoch [742], val_loss: 0.0890
# Epoch [743], val_loss: 0.0890
# Epoch [744], val_loss: 0.0890
# Epoch [745], val_loss: 0.0890
# Epoch [746], val_loss: 0.0890
# Epoch [747], val_loss: 0.0890
# Epoch [748], val_loss: 0.0890
# Epoch [749], val_loss: 0.0890
# Epoch [750], val_loss: 0.0890
# Epoch [751], val_loss: 0.0890
# Epoch [752], val_loss: 0.0890
# Epoch [753], val_loss: 0.0890
# Epoch [754], val_loss: 0.0890
# Epoch [755], val_loss: 0.0890
# Epoch [756], val_loss: 0.0890
# Epoch [757], val_loss: 0.0890
# Epoch [758], val_loss: 0.0890
# Epoch [759], val_loss: 0.0890
# Epoch [760], val_loss: 0.0890
# Epoch [761], val_loss: 0.0890
# Epoch [762], val_loss: 0.0890
# Epoch [763], val_loss: 0.0890
# Epoch [764], val_loss: 0.0890
# Epoch [765], val_loss: 0.0890
# Epoch [766], val_loss: 0.0890
# Epoch [767], val_loss: 0.0890
# Epoch [768], val_loss: 0.0890
# Epoch [769], val_loss: 0.0890
# Epoch [770], val_loss: 0.0890
# Epoch [771], val_loss: 0.0890
# Epoch [772], val_loss: 0.0890
# Epoch [773], val_loss: 0.0890
# Epoch [774], val_loss: 0.0890
# Epoch [775], val_loss: 0.0890
# Epoch [776], val_loss: 0.0890
# Epoch [777], val_loss: 0.0890
# Epoch [778], val_loss: 0.0890
# Epoch [779], val_loss: 0.0890
# Epoch [780], val_loss: 0.0890
# Epoch [781], val_loss: 0.0890
# Epoch [782], val_loss: 0.0890
# Epoch [783], val_loss: 0.0890
# Epoch [784], val_loss: 0.0890
# Epoch [785], val_loss: 0.0890
# Epoch [786], val_loss: 0.0890
# Epoch [787], val_loss: 0.0890
# Epoch [788], val_loss: 0.0890
# Epoch [789], val_loss: 0.0890
# Epoch [790], val_loss: 0.0890
# Epoch [791], val_loss: 0.0890
# Epoch [792], val_loss: 0.0890
# Epoch [793], val_loss: 0.0890
# Epoch [794], val_loss: 0.0890
# Epoch [795], val_loss: 0.0890
# Epoch [796], val_loss: 0.0890
# Epoch [797], val_loss: 0.0890
# Epoch [798], val_loss: 0.0890
# Epoch [799], val_loss: 0.0890
# Epoch [800], val_loss: 0.0890
# Epoch [801], val_loss: 0.0890
# Epoch [802], val_loss: 0.0890
# Epoch [803], val_loss: 0.0890
# Epoch [804], val_loss: 0.0890
# Epoch [805], val_loss: 0.0890
# Epoch [806], val_loss: 0.0890
# Epoch [807], val_loss: 0.0890
# Epoch [808], val_loss: 0.0890
# Epoch [809], val_loss: 0.0890
# Epoch [810], val_loss: 0.0890
# Epoch [811], val_loss: 0.0890
# Epoch [812], val_loss: 0.0890
# Epoch [813], val_loss: 0.0890
# Epoch [814], val_loss: 0.0890
# Epoch [815], val_loss: 0.0890
# Epoch [816], val_loss: 0.0890
# Epoch [817], val_loss: 0.0890
# Epoch [818], val_loss: 0.0890
# Epoch [819], val_loss: 0.0890
# Epoch [820], val_loss: 0.0890
# Epoch [821], val_loss: 0.0890
# Epoch [822], val_loss: 0.0890
# Epoch [823], val_loss: 0.0890
# Epoch [824], val_loss: 0.0890
# Epoch [825], val_loss: 0.0890
# Epoch [826], val_loss: 0.0890
# Epoch [827], val_loss: 0.0890
# Epoch [828], val_loss: 0.0890
# Epoch [829], val_loss: 0.0890
# Epoch [830], val_loss: 0.0890
# Epoch [831], val_loss: 0.0890
# Epoch [832], val_loss: 0.0890
# Epoch [833], val_loss: 0.0890
# Epoch [834], val_loss: 0.0890
# Epoch [835], val_loss: 0.0890
# Epoch [836], val_loss: 0.0890
# Epoch [837], val_loss: 0.0890
# Epoch [838], val_loss: 0.0890
# Epoch [839], val_loss: 0.0890
# Epoch [840], val_loss: 0.0890
# Epoch [841], val_loss: 0.0890
# Epoch [842], val_loss: 0.0890
# Epoch [843], val_loss: 0.0890
# Epoch [844], val_loss: 0.0890
# Epoch [845], val_loss: 0.0890
# Epoch [846], val_loss: 0.0890
# Epoch [847], val_loss: 0.0890
# Epoch [848], val_loss: 0.0890
# Epoch [849], val_loss: 0.0890
# Epoch [850], val_loss: 0.0890
# Epoch [851], val_loss: 0.0890
# Epoch [852], val_loss: 0.0890
# Epoch [853], val_loss: 0.0890
# Epoch [854], val_loss: 0.0890
# Epoch [855], val_loss: 0.0890
# Epoch [856], val_loss: 0.0890
# Epoch [857], val_loss: 0.0890
# Epoch [858], val_loss: 0.0890
# Epoch [859], val_loss: 0.0890
# Epoch [860], val_loss: 0.0890
# Epoch [861], val_loss: 0.0890
# Epoch [862], val_loss: 0.0890
# Epoch [863], val_loss: 0.0890
# Epoch [864], val_loss: 0.0890
# Epoch [865], val_loss: 0.0890
# Epoch [866], val_loss: 0.0890
# Epoch [867], val_loss: 0.0890
# Epoch [868], val_loss: 0.0890
# Epoch [869], val_loss: 0.0890
# Epoch [870], val_loss: 0.0890
# Epoch [871], val_loss: 0.0890
# Epoch [872], val_loss: 0.0890
# Epoch [873], val_loss: 0.0890
# Epoch [874], val_loss: 0.0890
# Epoch [875], val_loss: 0.0890
# Epoch [876], val_loss: 0.0890
# Epoch [877], val_loss: 0.0890
# Epoch [878], val_loss: 0.0890
# Epoch [879], val_loss: 0.0890
# Epoch [880], val_loss: 0.0890
# Epoch [881], val_loss: 0.0890
# Epoch [882], val_loss: 0.0890
# Epoch [883], val_loss: 0.0890
# Epoch [884], val_loss: 0.0890
# Epoch [885], val_loss: 0.0890
# Epoch [886], val_loss: 0.0890
# Epoch [887], val_loss: 0.0890
# Epoch [888], val_loss: 0.0890
# Epoch [889], val_loss: 0.0890
# Epoch [890], val_loss: 0.0890
# Epoch [891], val_loss: 0.0890
# Epoch [892], val_loss: 0.0890
# Epoch [893], val_loss: 0.0890
# Epoch [894], val_loss: 0.0890
# Epoch [895], val_loss: 0.0890
# Epoch [896], val_loss: 0.0890
# Epoch [897], val_loss: 0.0890
# Epoch [898], val_loss: 0.0890
# Epoch [899], val_loss: 0.0890
# Epoch [900], val_loss: 0.0890
# Epoch [901], val_loss: 0.0890
# Epoch [902], val_loss: 0.0890
# Epoch [903], val_loss: 0.0890
# Epoch [904], val_loss: 0.0890
# Epoch [905], val_loss: 0.0890
# Epoch [906], val_loss: 0.0890
# Epoch [907], val_loss: 0.0890
# Epoch [908], val_loss: 0.0890
# Epoch [909], val_loss: 0.0890
# Epoch [910], val_loss: 0.0890
# Epoch [911], val_loss: 0.0890
# Epoch [912], val_loss: 0.0890
# Epoch [913], val_loss: 0.0890
# Epoch [914], val_loss: 0.0890
# Epoch [915], val_loss: 0.0890
# Epoch [916], val_loss: 0.0890
# Epoch [917], val_loss: 0.0890
# Epoch [918], val_loss: 0.0890
# Epoch [919], val_loss: 0.0890
# Epoch [920], val_loss: 0.0890
# Epoch [921], val_loss: 0.0890
# Epoch [922], val_loss: 0.0890
# Epoch [923], val_loss: 0.0890
# Epoch [924], val_loss: 0.0890
# Epoch [925], val_loss: 0.0890
# Epoch [926], val_loss: 0.0890
# Epoch [927], val_loss: 0.0890
# Epoch [928], val_loss: 0.0890
# Epoch [929], val_loss: 0.0890
# Epoch [930], val_loss: 0.0890
# Epoch [931], val_loss: 0.0890
# Epoch [932], val_loss: 0.0890
# Epoch [933], val_loss: 0.0890
# Epoch [934], val_loss: 0.0890
# Epoch [935], val_loss: 0.0890
# Epoch [936], val_loss: 0.0890
# Epoch [937], val_loss: 0.0890
# Epoch [938], val_loss: 0.0890
# Epoch [939], val_loss: 0.0890
# Epoch [940], val_loss: 0.0890
# Epoch [941], val_loss: 0.0890
# Epoch [942], val_loss: 0.0890
# Epoch [943], val_loss: 0.0890
# Epoch [944], val_loss: 0.0890
# Epoch [945], val_loss: 0.0890
# Epoch [946], val_loss: 0.0890
# Epoch [947], val_loss: 0.0890
# Epoch [948], val_loss: 0.0890
# Epoch [949], val_loss: 0.0890
# Epoch [950], val_loss: 0.0890
# Epoch [951], val_loss: 0.0890
# Epoch [952], val_loss: 0.0890
# Epoch [953], val_loss: 0.0890
# Epoch [954], val_loss: 0.0890
# Epoch [955], val_loss: 0.0890
# Epoch [956], val_loss: 0.0890
# Epoch [957], val_loss: 0.0890
# Epoch [958], val_loss: 0.0890
# Epoch [959], val_loss: 0.0890
# Epoch [960], val_loss: 0.0890
# Epoch [961], val_loss: 0.0890
# Epoch [962], val_loss: 0.0890
# Epoch [963], val_loss: 0.0890
# Epoch [964], val_loss: 0.0890
# Epoch [965], val_loss: 0.0890
# Epoch [966], val_loss: 0.0890
# Epoch [967], val_loss: 0.0890
# Epoch [968], val_loss: 0.0890
# Epoch [969], val_loss: 0.0890
# Epoch [970], val_loss: 0.0890
# Epoch [971], val_loss: 0.0890
# Epoch [972], val_loss: 0.0890
# Epoch [973], val_loss: 0.0890
# Epoch [974], val_loss: 0.0890
# Epoch [975], val_loss: 0.0890
# Epoch [976], val_loss: 0.0890
# Epoch [977], val_loss: 0.0890
# Epoch [978], val_loss: 0.0890
# Epoch [979], val_loss: 0.0890
# Epoch [980], val_loss: 0.0890
# Epoch [981], val_loss: 0.0890
# Epoch [982], val_loss: 0.0890
# Epoch [983], val_loss: 0.0890
# Epoch [984], val_loss: 0.0890
# Epoch [985], val_loss: 0.0890
# Epoch [986], val_loss: 0.0890
# Epoch [987], val_loss: 0.0890
# Epoch [988], val_loss: 0.0890
# Epoch [989], val_loss: 0.0890
# Epoch [990], val_loss: 0.0890
# Epoch [991], val_loss: 0.0890
# Epoch [992], val_loss: 0.0890
# Epoch [993], val_loss: 0.0890
# Epoch [994], val_loss: 0.0890
# Epoch [995], val_loss: 0.0890
# Epoch [996], val_loss: 0.0890
# Epoch [997], val_loss: 0.0890
# Epoch [998], val_loss: 0.0890
# Epoch [999], val_loss: 0.0890
# Epoch [1000], val_loss: 0.0890
# Epoch [1001], val_loss: 0.0890
# Epoch [1002], val_loss: 0.0890
# Epoch [1003], val_loss: 0.0890
# Epoch [1004], val_loss: 0.0890
# Epoch [1005], val_loss: 0.0890
# Epoch [1006], val_loss: 0.0890
# Epoch [1007], val_loss: 0.0890
# Epoch [1008], val_loss: 0.0890
# Epoch [1009], val_loss: 0.0890
# Epoch [1010], val_loss: 0.0890
# Epoch [1011], val_loss: 0.0890
# Epoch [1012], val_loss: 0.0890
# Epoch [1013], val_loss: 0.0890
# Epoch [1014], val_loss: 0.0890
# Epoch [1015], val_loss: 0.0890
# Epoch [1016], val_loss: 0.0890
# Epoch [1017], val_loss: 0.0890
# Epoch [1018], val_loss: 0.0890
# Epoch [1019], val_loss: 0.0890
# Epoch [1020], val_loss: 0.0890
# Epoch [1021], val_loss: 0.0890
# Epoch [1022], val_loss: 0.0890
# Epoch [1023], val_loss: 0.0890
# Epoch [1024], val_loss: 0.0890
# Epoch [1025], val_loss: 0.0890
# Epoch [1026], val_loss: 0.0890
# Epoch [1027], val_loss: 0.0890
# Epoch [1028], val_loss: 0.0890
# Epoch [1029], val_loss: 0.0890
# Epoch [1030], val_loss: 0.0890
# Epoch [1031], val_loss: 0.0890
# Epoch [1032], val_loss: 0.0890
# Epoch [1033], val_loss: 0.0890
# Epoch [1034], val_loss: 0.0890
# Epoch [1035], val_loss: 0.0890
# Epoch [1036], val_loss: 0.0890
# Epoch [1037], val_loss: 0.0890
# Epoch [1038], val_loss: 0.0890
# Epoch [1039], val_loss: 0.0890
# Epoch [1040], val_loss: 0.0890
# Epoch [1041], val_loss: 0.0890
# Epoch [1042], val_loss: 0.0890
# Epoch [1043], val_loss: 0.0890
# Epoch [1044], val_loss: 0.0890
# Epoch [1045], val_loss: 0.0890
# Epoch [1046], val_loss: 0.0890
# Epoch [1047], val_loss: 0.0890
# Epoch [1048], val_loss: 0.0890
# Epoch [1049], val_loss: 0.0890
# Epoch [1050], val_loss: 0.0890
# Epoch [1051], val_loss: 0.0890
# Epoch [1052], val_loss: 0.0890
# Epoch [1053], val_loss: 0.0890
# Epoch [1054], val_loss: 0.0890
# Epoch [1055], val_loss: 0.0890
# Epoch [1056], val_loss: 0.0890
# Epoch [1057], val_loss: 0.0890
# Epoch [1058], val_loss: 0.0890
# Epoch [1059], val_loss: 0.0890
# Epoch [1060], val_loss: 0.0890
# Epoch [1061], val_loss: 0.0890
# Epoch [1062], val_loss: 0.0890
# Epoch [1063], val_loss: 0.0890
# Epoch [1064], val_loss: 0.0890
# Epoch [1065], val_loss: 0.0890
# Epoch [1066], val_loss: 0.0890
# Epoch [1067], val_loss: 0.0890
# Epoch [1068], val_loss: 0.0890
# Epoch [1069], val_loss: 0.0890
# Epoch [1070], val_loss: 0.0890
# Epoch [1071], val_loss: 0.0890
# Epoch [1072], val_loss: 0.0890
# Epoch [1073], val_loss: 0.0890
# Epoch [1074], val_loss: 0.0890
# Epoch [1075], val_loss: 0.0890
# Epoch [1076], val_loss: 0.0890
# Epoch [1077], val_loss: 0.0890
# Epoch [1078], val_loss: 0.0890
# Epoch [1079], val_loss: 0.0890
# Epoch [1080], val_loss: 0.0890
# Epoch [1081], val_loss: 0.0890
# Epoch [1082], val_loss: 0.0890
# Epoch [1083], val_loss: 0.0890
# Epoch [1084], val_loss: 0.0890
# Epoch [1085], val_loss: 0.0890
# Epoch [1086], val_loss: 0.0890
# Epoch [1087], val_loss: 0.0890
# Epoch [1088], val_loss: 0.0890
# Epoch [1089], val_loss: 0.0890
# Epoch [1090], val_loss: 0.0890
# Epoch [1091], val_loss: 0.0890
# Epoch [1092], val_loss: 0.0890
# Epoch [1093], val_loss: 0.0890
# Epoch [1094], val_loss: 0.0890
# Epoch [1095], val_loss: 0.0890
# Epoch [1096], val_loss: 0.0890
# Epoch [1097], val_loss: 0.0890
# Epoch [1098], val_loss: 0.0890
# Epoch [1099], val_loss: 0.0890
# Epoch [1100], val_loss: 0.0890
# Epoch [1101], val_loss: 0.0890
# Epoch [1102], val_loss: 0.0890
# Epoch [1103], val_loss: 0.0890
# Epoch [1104], val_loss: 0.0890
# Epoch [1105], val_loss: 0.0890
# Epoch [1106], val_loss: 0.0890
# Epoch [1107], val_loss: 0.0890
# Epoch [1108], val_loss: 0.0890
# Epoch [1109], val_loss: 0.0890
# Epoch [1110], val_loss: 0.0890
# Epoch [1111], val_loss: 0.0890
# Epoch [1112], val_loss: 0.0890
# Epoch [1113], val_loss: 0.0890
# Epoch [1114], val_loss: 0.0890
# Epoch [1115], val_loss: 0.0890
# Epoch [1116], val_loss: 0.0890
# Epoch [1117], val_loss: 0.0890
# Epoch [1118], val_loss: 0.0890
# Epoch [1119], val_loss: 0.0890
# Epoch [1120], val_loss: 0.0890
# Epoch [1121], val_loss: 0.0890
# Epoch [1122], val_loss: 0.0890
# Epoch [1123], val_loss: 0.0890
# Epoch [1124], val_loss: 0.0890
# Epoch [1125], val_loss: 0.0890
# Epoch [1126], val_loss: 0.0890
# Epoch [1127], val_loss: 0.0890
# Epoch [1128], val_loss: 0.0890
# Epoch [1129], val_loss: 0.0890
# Epoch [1130], val_loss: 0.0890
# Epoch [1131], val_loss: 0.0890
# Epoch [1132], val_loss: 0.0890
# Epoch [1133], val_loss: 0.0890
# Epoch [1134], val_loss: 0.0890
# Epoch [1135], val_loss: 0.0890
# Epoch [1136], val_loss: 0.0890
# Epoch [1137], val_loss: 0.0890
# Epoch [1138], val_loss: 0.0890
# Epoch [1139], val_loss: 0.0890
# Epoch [1140], val_loss: 0.0890
# Epoch [1141], val_loss: 0.0890
# Epoch [1142], val_loss: 0.0890
# Epoch [1143], val_loss: 0.0890
# Epoch [1144], val_loss: 0.0890
# Epoch [1145], val_loss: 0.0890
# Epoch [1146], val_loss: 0.0890
# Epoch [1147], val_loss: 0.0890
# Epoch [1148], val_loss: 0.0890
# Epoch [1149], val_loss: 0.0890
# Epoch [1150], val_loss: 0.0890
# Epoch [1151], val_loss: 0.0890
# Epoch [1152], val_loss: 0.0890
# Epoch [1153], val_loss: 0.0890
# Epoch [1154], val_loss: 0.0890
# Epoch [1155], val_loss: 0.0890
# Epoch [1156], val_loss: 0.0890
# Epoch [1157], val_loss: 0.0890
# Epoch [1158], val_loss: 0.0890
# Epoch [1159], val_loss: 0.0890
# Epoch [1160], val_loss: 0.0890
# Epoch [1161], val_loss: 0.0890
# Epoch [1162], val_loss: 0.0890
# Epoch [1163], val_loss: 0.0890
# Epoch [1164], val_loss: 0.0890
# Epoch [1165], val_loss: 0.0890
# Epoch [1166], val_loss: 0.0890
# Epoch [1167], val_loss: 0.0890
# Epoch [1168], val_loss: 0.0890
# Epoch [1169], val_loss: 0.0890
# Epoch [1170], val_loss: 0.0890
# Epoch [1171], val_loss: 0.0890
# Epoch [1172], val_loss: 0.0890
# Epoch [1173], val_loss: 0.0890
# Epoch [1174], val_loss: 0.0890
# Epoch [1175], val_loss: 0.0890
# Epoch [1176], val_loss: 0.0890
# Epoch [1177], val_loss: 0.0890
# Epoch [1178], val_loss: 0.0890
# Epoch [1179], val_loss: 0.0890
# Epoch [1180], val_loss: 0.0890
# Epoch [1181], val_loss: 0.0890
# Epoch [1182], val_loss: 0.0890
# Epoch [1183], val_loss: 0.0890
# Epoch [1184], val_loss: 0.0890
# Epoch [1185], val_loss: 0.0890
# Epoch [1186], val_loss: 0.0890
# Epoch [1187], val_loss: 0.0890
# Epoch [1188], val_loss: 0.0890
# Epoch [1189], val_loss: 0.0890
# Epoch [1190], val_loss: 0.0890
# Epoch [1191], val_loss: 0.0890
# Epoch [1192], val_loss: 0.0890
# Epoch [1193], val_loss: 0.0890
# Epoch [1194], val_loss: 0.0890
# Epoch [1195], val_loss: 0.0890
# Epoch [1196], val_loss: 0.0890
# Epoch [1197], val_loss: 0.0890
# Epoch [1198], val_loss: 0.0890
# Epoch [1199], val_loss: 0.0890
# Epoch [1200], val_loss: 0.0890
# Epoch [1201], val_loss: 0.0890
# Epoch [1202], val_loss: 0.0890
# Epoch [1203], val_loss: 0.0890
# Epoch [1204], val_loss: 0.0890
# Epoch [1205], val_loss: 0.0890
# Epoch [1206], val_loss: 0.0890
# Epoch [1207], val_loss: 0.0890
# Epoch [1208], val_loss: 0.0890
# Epoch [1209], val_loss: 0.0890
# Epoch [1210], val_loss: 0.0890
# Epoch [1211], val_loss: 0.0890
# Epoch [1212], val_loss: 0.0890
# Epoch [1213], val_loss: 0.0890
# Epoch [1214], val_loss: 0.0890
# Epoch [1215], val_loss: 0.0890
# Epoch [1216], val_loss: 0.0890
# Epoch [1217], val_loss: 0.0890
# Epoch [1218], val_loss: 0.0890
# Epoch [1219], val_loss: 0.0890
# Epoch [1220], val_loss: 0.0890
# Epoch [1221], val_loss: 0.0890
# Epoch [1222], val_loss: 0.0890
# Epoch [1223], val_loss: 0.0890
# Epoch [1224], val_loss: 0.0890
# Epoch [1225], val_loss: 0.0890
# Epoch [1226], val_loss: 0.0890
# Epoch [1227], val_loss: 0.0890
# Epoch [1228], val_loss: 0.0890
# Epoch [1229], val_loss: 0.0890
# Epoch [1230], val_loss: 0.0890
# Epoch [1231], val_loss: 0.0890
# Epoch [1232], val_loss: 0.0890
# Epoch [1233], val_loss: 0.0890
# Epoch [1234], val_loss: 0.0890
# Epoch [1235], val_loss: 0.0890
# Epoch [1236], val_loss: 0.0890
# Epoch [1237], val_loss: 0.0890
# Epoch [1238], val_loss: 0.0890
# Epoch [1239], val_loss: 0.0890
# Epoch [1240], val_loss: 0.0890
# Epoch [1241], val_loss: 0.0890
# Epoch [1242], val_loss: 0.0890
# Epoch [1243], val_loss: 0.0890
# Epoch [1244], val_loss: 0.0890
# Epoch [1245], val_loss: 0.0890
# Epoch [1246], val_loss: 0.0890
# Epoch [1247], val_loss: 0.0890
# Epoch [1248], val_loss: 0.0890
# Epoch [1249], val_loss: 0.0890
# Epoch [1250], val_loss: 0.0890
# Epoch [1251], val_loss: 0.0890
# Epoch [1252], val_loss: 0.0890
# Epoch [1253], val_loss: 0.0890
# Epoch [1254], val_loss: 0.0890
# Epoch [1255], val_loss: 0.0890
# Epoch [1256], val_loss: 0.0890
# Epoch [1257], val_loss: 0.0890
# Epoch [1258], val_loss: 0.0890
# Epoch [1259], val_loss: 0.0890
# Epoch [1260], val_loss: 0.0890
# Epoch [1261], val_loss: 0.0890
# Epoch [1262], val_loss: 0.0890
# Epoch [1263], val_loss: 0.0890
# Epoch [1264], val_loss: 0.0890
# Epoch [1265], val_loss: 0.0890
# Epoch [1266], val_loss: 0.0890
# Epoch [1267], val_loss: 0.0890
# Epoch [1268], val_loss: 0.0890
# Epoch [1269], val_loss: 0.0890
# Epoch [1270], val_loss: 0.0890
# Epoch [1271], val_loss: 0.0890
# Epoch [1272], val_loss: 0.0890
# Epoch [1273], val_loss: 0.0890
# Epoch [1274], val_loss: 0.0890
# Epoch [1275], val_loss: 0.0890
# Epoch [1276], val_loss: 0.0890
# Epoch [1277], val_loss: 0.0890
# Epoch [1278], val_loss: 0.0890
# Epoch [1279], val_loss: 0.0890
# Epoch [1280], val_loss: 0.0890
# Epoch [1281], val_loss: 0.0890
# Epoch [1282], val_loss: 0.0890
# Epoch [1283], val_loss: 0.0890
# Epoch [1284], val_loss: 0.0890
# Epoch [1285], val_loss: 0.0890
# Epoch [1286], val_loss: 0.0890
# Epoch [1287], val_loss: 0.0890
# Epoch [1288], val_loss: 0.0890
# Epoch [1289], val_loss: 0.0890
# Epoch [1290], val_loss: 0.0890
# Epoch [1291], val_loss: 0.0890
# Epoch [1292], val_loss: 0.0890
# Epoch [1293], val_loss: 0.0890
# Epoch [1294], val_loss: 0.0890
# Epoch [1295], val_loss: 0.0890
# Epoch [1296], val_loss: 0.0890
# Epoch [1297], val_loss: 0.0890
# Epoch [1298], val_loss: 0.0890
# Epoch [1299], val_loss: 0.0890
# Epoch [1300], val_loss: 0.0890
# Epoch [1301], val_loss: 0.0890
# Epoch [1302], val_loss: 0.0890
# Epoch [1303], val_loss: 0.0890
# Epoch [1304], val_loss: 0.0890
# Epoch [1305], val_loss: 0.0890
# Epoch [1306], val_loss: 0.0890
# Epoch [1307], val_loss: 0.0890
# Epoch [1308], val_loss: 0.0890
# Epoch [1309], val_loss: 0.0890
# Epoch [1310], val_loss: 0.0890
# Epoch [1311], val_loss: 0.0890
# Epoch [1312], val_loss: 0.0890
# Epoch [1313], val_loss: 0.0890
# Epoch [1314], val_loss: 0.0890
# Epoch [1315], val_loss: 0.0890
# Epoch [1316], val_loss: 0.0890
# Epoch [1317], val_loss: 0.0890
# Epoch [1318], val_loss: 0.0890
# Epoch [1319], val_loss: 0.0890
# Epoch [1320], val_loss: 0.0890
# Epoch [1321], val_loss: 0.0890
# Epoch [1322], val_loss: 0.0890
# Epoch [1323], val_loss: 0.0890
# Epoch [1324], val_loss: 0.0890
# Epoch [1325], val_loss: 0.0890
# Epoch [1326], val_loss: 0.0890
# Epoch [1327], val_loss: 0.0890
# Epoch [1328], val_loss: 0.0890
# Epoch [1329], val_loss: 0.0890
# Epoch [1330], val_loss: 0.0890
# Epoch [1331], val_loss: 0.0890
# Epoch [1332], val_loss: 0.0890
# Epoch [1333], val_loss: 0.0890
# Epoch [1334], val_loss: 0.0890
# Epoch [1335], val_loss: 0.0890
# Epoch [1336], val_loss: 0.0890
# Epoch [1337], val_loss: 0.0890
# Epoch [1338], val_loss: 0.0890
# Epoch [1339], val_loss: 0.0890
# Epoch [1340], val_loss: 0.0890
# Epoch [1341], val_loss: 0.0890
# Epoch [1342], val_loss: 0.0890
# Epoch [1343], val_loss: 0.0890
# Epoch [1344], val_loss: 0.0890
# Epoch [1345], val_loss: 0.0890
# Epoch [1346], val_loss: 0.0890
# Epoch [1347], val_loss: 0.0890
# Epoch [1348], val_loss: 0.0890
# Epoch [1349], val_loss: 0.0890
# Epoch [1350], val_loss: 0.0890
# Epoch [1351], val_loss: 0.0890
# Epoch [1352], val_loss: 0.0890
# Epoch [1353], val_loss: 0.0890
# Epoch [1354], val_loss: 0.0890
# Epoch [1355], val_loss: 0.0890
# Epoch [1356], val_loss: 0.0890
# Epoch [1357], val_loss: 0.0890
# Epoch [1358], val_loss: 0.0890
# Epoch [1359], val_loss: 0.0890
# Epoch [1360], val_loss: 0.0890
# Epoch [1361], val_loss: 0.0890
# Epoch [1362], val_loss: 0.0890
# Epoch [1363], val_loss: 0.0890
# Epoch [1364], val_loss: 0.0890
# Epoch [1365], val_loss: 0.0890
# Epoch [1366], val_loss: 0.0890
# Epoch [1367], val_loss: 0.0890
# Epoch [1368], val_loss: 0.0890
# Epoch [1369], val_loss: 0.0890
# Epoch [1370], val_loss: 0.0890
# Epoch [1371], val_loss: 0.0890
# Epoch [1372], val_loss: 0.0890
# Epoch [1373], val_loss: 0.0890
# Epoch [1374], val_loss: 0.0890
# Epoch [1375], val_loss: 0.0890
# Epoch [1376], val_loss: 0.0890
# Epoch [1377], val_loss: 0.0890
# Epoch [1378], val_loss: 0.0890
# Epoch [1379], val_loss: 0.0890
# Epoch [1380], val_loss: 0.0890
# Epoch [1381], val_loss: 0.0890
# Epoch [1382], val_loss: 0.0890
# Epoch [1383], val_loss: 0.0890
# Epoch [1384], val_loss: 0.0890
# Epoch [1385], val_loss: 0.0890
# Epoch [1386], val_loss: 0.0890
# Epoch [1387], val_loss: 0.0890
# Epoch [1388], val_loss: 0.0890
# Epoch [1389], val_loss: 0.0890
# Epoch [1390], val_loss: 0.0890
# Epoch [1391], val_loss: 0.0890
# Epoch [1392], val_loss: 0.0890
# Epoch [1393], val_loss: 0.0890
# Epoch [1394], val_loss: 0.0890
# Epoch [1395], val_loss: 0.0890
# Epoch [1396], val_loss: 0.0890
# Epoch [1397], val_loss: 0.0890
# Epoch [1398], val_loss: 0.0890
# Epoch [1399], val_loss: 0.0890
# Epoch [1400], val_loss: 0.0890
# Epoch [1401], val_loss: 0.0890
# Epoch [1402], val_loss: 0.0890
# Epoch [1403], val_loss: 0.0890
# Epoch [1404], val_loss: 0.0890
# Epoch [1405], val_loss: 0.0890
# Epoch [1406], val_loss: 0.0890
# Epoch [1407], val_loss: 0.0890
# Epoch [1408], val_loss: 0.0890
# Epoch [1409], val_loss: 0.0890
# Epoch [1410], val_loss: 0.0890
# Epoch [1411], val_loss: 0.0890
# Epoch [1412], val_loss: 0.0890
# Epoch [1413], val_loss: 0.0890
# Epoch [1414], val_loss: 0.0890
# Epoch [1415], val_loss: 0.0890
# Epoch [1416], val_loss: 0.0890
# Epoch [1417], val_loss: 0.0890
# Epoch [1418], val_loss: 0.0890
# Epoch [1419], val_loss: 0.0890
# Epoch [1420], val_loss: 0.0890
# Epoch [1421], val_loss: 0.0890
# Epoch [1422], val_loss: 0.0890
# Epoch [1423], val_loss: 0.0890
# Epoch [1424], val_loss: 0.0890
# Epoch [1425], val_loss: 0.0890
# Epoch [1426], val_loss: 0.0890
# Epoch [1427], val_loss: 0.0890
# Epoch [1428], val_loss: 0.0890
# Epoch [1429], val_loss: 0.0890
# Epoch [1430], val_loss: 0.0890
# Epoch [1431], val_loss: 0.0890
# Epoch [1432], val_loss: 0.0890
# Epoch [1433], val_loss: 0.0890
# Epoch [1434], val_loss: 0.0890
# Epoch [1435], val_loss: 0.0890
# Epoch [1436], val_loss: 0.0890
# Epoch [1437], val_loss: 0.0890
# Epoch [1438], val_loss: 0.0890
# Epoch [1439], val_loss: 0.0890
# Epoch [1440], val_loss: 0.0890
# Epoch [1441], val_loss: 0.0890
# Epoch [1442], val_loss: 0.0890
# Epoch [1443], val_loss: 0.0890
# Epoch [1444], val_loss: 0.0890
# Epoch [1445], val_loss: 0.0890
# Epoch [1446], val_loss: 0.0890
# Epoch [1447], val_loss: 0.0890
# Epoch [1448], val_loss: 0.0890
# Epoch [1449], val_loss: 0.0890
# Epoch [1450], val_loss: 0.0890
# Epoch [1451], val_loss: 0.0890
# Epoch [1452], val_loss: 0.0890
# Epoch [1453], val_loss: 0.0890
# Epoch [1454], val_loss: 0.0890
# Epoch [1455], val_loss: 0.0890
# Epoch [1456], val_loss: 0.0890
# Epoch [1457], val_loss: 0.0890
# Epoch [1458], val_loss: 0.0890
# Epoch [1459], val_loss: 0.0890
# Epoch [1460], val_loss: 0.0890
# Epoch [1461], val_loss: 0.0890
# Epoch [1462], val_loss: 0.0890
# Epoch [1463], val_loss: 0.0890
# Epoch [1464], val_loss: 0.0890
# Epoch [1465], val_loss: 0.0890
# Epoch [1466], val_loss: 0.0890
# Epoch [1467], val_loss: 0.0890
# Epoch [1468], val_loss: 0.0890
# Epoch [1469], val_loss: 0.0890
# Epoch [1470], val_loss: 0.0890
# Epoch [1471], val_loss: 0.0890
# Epoch [1472], val_loss: 0.0890
# Epoch [1473], val_loss: 0.0890
# Epoch [1474], val_loss: 0.0890
# Epoch [1475], val_loss: 0.0890
# Epoch [1476], val_loss: 0.0890
# Epoch [1477], val_loss: 0.0890
# Epoch [1478], val_loss: 0.0890
# Epoch [1479], val_loss: 0.0890
# Epoch [1480], val_loss: 0.0890
# Epoch [1481], val_loss: 0.0890
# Epoch [1482], val_loss: 0.0890
# Epoch [1483], val_loss: 0.0890
# Epoch [1484], val_loss: 0.0890
# Epoch [1485], val_loss: 0.0890
# Epoch [1486], val_loss: 0.0890
# Epoch [1487], val_loss: 0.0890
# Epoch [1488], val_loss: 0.0890
# Epoch [1489], val_loss: 0.0890
# Epoch [1490], val_loss: 0.0890
# Epoch [1491], val_loss: 0.0890
# Epoch [1492], val_loss: 0.0890
# Epoch [1493], val_loss: 0.0890
# Epoch [1494], val_loss: 0.0890
# Epoch [1495], val_loss: 0.0890
# Epoch [1496], val_loss: 0.0890
# Epoch [1497], val_loss: 0.0890
# Epoch [1498], val_loss: 0.0890
# Epoch [1499], val_loss: 0.0890
# Epoch [1500], val_loss: 0.0890
# Epoch [1501], val_loss: 0.0890
# Epoch [1502], val_loss: 0.0890
# Epoch [1503], val_loss: 0.0890
# Epoch [1504], val_loss: 0.0890
# Epoch [1505], val_loss: 0.0890
# Epoch [1506], val_loss: 0.0890
# Epoch [1507], val_loss: 0.0890
# Epoch [1508], val_loss: 0.0890
# Epoch [1509], val_loss: 0.0890
# Epoch [1510], val_loss: 0.0890
# Epoch [1511], val_loss: 0.0890
# Epoch [1512], val_loss: 0.0890
# Epoch [1513], val_loss: 0.0890
# Epoch [1514], val_loss: 0.0890
# Epoch [1515], val_loss: 0.0890
# Epoch [1516], val_loss: 0.0890
# Epoch [1517], val_loss: 0.0890
# Epoch [1518], val_loss: 0.0890
# Epoch [1519], val_loss: 0.0890
# Epoch [1520], val_loss: 0.0890
# Epoch [1521], val_loss: 0.0890
# Epoch [1522], val_loss: 0.0890
# Epoch [1523], val_loss: 0.0890
# Epoch [1524], val_loss: 0.0890
# Epoch [1525], val_loss: 0.0890
# Epoch [1526], val_loss: 0.0890
# Epoch [1527], val_loss: 0.0890
# Epoch [1528], val_loss: 0.0890
# Epoch [1529], val_loss: 0.0890
# Epoch [1530], val_loss: 0.0890
# Epoch [1531], val_loss: 0.0890
# Epoch [1532], val_loss: 0.0890
# Epoch [1533], val_loss: 0.0890
# Epoch [1534], val_loss: 0.0890
# Epoch [1535], val_loss: 0.0890
# Epoch [1536], val_loss: 0.0890
# Epoch [1537], val_loss: 0.0890
# Epoch [1538], val_loss: 0.0890
# Epoch [1539], val_loss: 0.0890
# Epoch [1540], val_loss: 0.0890
# Epoch [1541], val_loss: 0.0890
# Epoch [1542], val_loss: 0.0890
# Epoch [1543], val_loss: 0.0890
# Epoch [1544], val_loss: 0.0890
# Epoch [1545], val_loss: 0.0890
# Epoch [1546], val_loss: 0.0890
# Epoch [1547], val_loss: 0.0890
# Epoch [1548], val_loss: 0.0890
# Epoch [1549], val_loss: 0.0890
# Epoch [1550], val_loss: 0.0890
# Epoch [1551], val_loss: 0.0890
# Epoch [1552], val_loss: 0.0890
# Epoch [1553], val_loss: 0.0890
# Epoch [1554], val_loss: 0.0890
# Epoch [1555], val_loss: 0.0890
# Epoch [1556], val_loss: 0.0890
# Epoch [1557], val_loss: 0.0890
# Epoch [1558], val_loss: 0.0890
# Epoch [1559], val_loss: 0.0890
# Epoch [1560], val_loss: 0.0890
# Epoch [1561], val_loss: 0.0890
# Epoch [1562], val_loss: 0.0890
# Epoch [1563], val_loss: 0.0890
# Epoch [1564], val_loss: 0.0890
# Epoch [1565], val_loss: 0.0890
# Epoch [1566], val_loss: 0.0890
# Epoch [1567], val_loss: 0.0890
# Epoch [1568], val_loss: 0.0890
# Epoch [1569], val_loss: 0.0890
# Epoch [1570], val_loss: 0.0890
# Epoch [1571], val_loss: 0.0890
# Epoch [1572], val_loss: 0.0890
# Epoch [1573], val_loss: 0.0890
# Epoch [1574], val_loss: 0.0890
# Epoch [1575], val_loss: 0.0890
# Epoch [1576], val_loss: 0.0890
# Epoch [1577], val_loss: 0.0890
# Epoch [1578], val_loss: 0.0890
# Epoch [1579], val_loss: 0.0890
# Epoch [1580], val_loss: 0.0890
# Epoch [1581], val_loss: 0.0890
# Epoch [1582], val_loss: 0.0890
# Epoch [1583], val_loss: 0.0890
# ...
# Epoch [19500], val_loss: 0.0889
# Epoch [19501], val_loss: 0.0889
# Epoch [19502], val_loss: 0.0889
# Epoch [19503], val_loss: 0.0889
# Epoch [19504], val_loss: 0.0889
# Epoch [19505], val_loss: 0.0889
# Epoch [19506], val_loss: 0.0889
# Epoch [19507], val_loss: 0.0889
# Epoch [19508], val_loss: 0.0889
# Epoch [19509], val_loss: 0.0889
# Epoch [19510], val_loss: 0.0889
# Epoch [19511], val_loss: 0.0889
# Epoch [19512], val_loss: 0.0889
# Epoch [19513], val_loss: 0.0889
# Epoch [19514], val_loss: 0.0889
# Epoch [19515], val_loss: 0.0889
# Epoch [19516], val_loss: 0.0889
# Epoch [19517], val_loss: 0.0889
# Epoch [19518], val_loss: 0.0889
# Epoch [19519], val_loss: 0.0889
# Epoch [19520], val_loss: 0.0889
# Epoch [19521], val_loss: 0.0889
# Epoch [19522], val_loss: 0.0889
# Epoch [19523], val_loss: 0.0889
# Epoch [19524], val_loss: 0.0889
# Epoch [19525], val_loss: 0.0889
# Epoch [19526], val_loss: 0.0889
# Epoch [19527], val_loss: 0.0889
# Epoch [19528], val_loss: 0.0889
# Epoch [19529], val_loss: 0.0889
# Epoch [19530], val_loss: 0.0889
# Epoch [19531], val_loss: 0.0889
# Epoch [19532], val_loss: 0.0889
# Epoch [19533], val_loss: 0.0889
# Epoch [19534], val_loss: 0.0889
# Epoch [19535], val_loss: 0.0889
# Epoch [19536], val_loss: 0.0889
# Epoch [19537], val_loss: 0.0889
# Epoch [19538], val_loss: 0.0889
# Epoch [19539], val_loss: 0.0889
# Epoch [19540], val_loss: 0.0889
# Epoch [19541], val_loss: 0.0889
# Epoch [19542], val_loss: 0.0889
# Epoch [19543], val_loss: 0.0889
# Epoch [19544], val_loss: 0.0889
# Epoch [19545], val_loss: 0.0889
# Epoch [19546], val_loss: 0.0889
# Epoch [19547], val_loss: 0.0889
# Epoch [19548], val_loss: 0.0889
# Epoch [19549], val_loss: 0.0889
# Epoch [19550], val_loss: 0.0889
# Epoch [19551], val_loss: 0.0889
# Epoch [19552], val_loss: 0.0889
# Epoch [19553], val_loss: 0.0889
# Epoch [19554], val_loss: 0.0889
# Epoch [19555], val_loss: 0.0889
# Epoch [19556], val_loss: 0.0889
# Epoch [19557], val_loss: 0.0889
# Epoch [19558], val_loss: 0.0889
# Epoch [19559], val_loss: 0.0889
# Epoch [19560], val_loss: 0.0889
# Epoch [19561], val_loss: 0.0889
# Epoch [19562], val_loss: 0.0889
# Epoch [19563], val_loss: 0.0889
# Epoch [19564], val_loss: 0.0889
# Epoch [19565], val_loss: 0.0889
# Epoch [19566], val_loss: 0.0889
# Epoch [19567], val_loss: 0.0889
# Epoch [19568], val_loss: 0.0889
# Epoch [19569], val_loss: 0.0889
# Epoch [19570], val_loss: 0.0889
# Epoch [19571], val_loss: 0.0889
# Epoch [19572], val_loss: 0.0889
# Epoch [19573], val_loss: 0.0889
# Epoch [19574], val_loss: 0.0889
# Epoch [19575], val_loss: 0.0889
# Epoch [19576], val_loss: 0.0889
# Epoch [19577], val_loss: 0.0889
# Epoch [19578], val_loss: 0.0889
# Epoch [19579], val_loss: 0.0889
# Epoch [19580], val_loss: 0.0889
# Epoch [19581], val_loss: 0.0889
# Epoch [19582], val_loss: 0.0889
# Epoch [19583], val_loss: 0.0889
# Epoch [19584], val_loss: 0.0889
# Epoch [19585], val_loss: 0.0889
# Epoch [19586], val_loss: 0.0889
# Epoch [19587], val_loss: 0.0889
# Epoch [19588], val_loss: 0.0889
# Epoch [19589], val_loss: 0.0889
# Epoch [19590], val_loss: 0.0889
# Epoch [19591], val_loss: 0.0889
# Epoch [19592], val_loss: 0.0889
# Epoch [19593], val_loss: 0.0889
# Epoch [19594], val_loss: 0.0889
# Epoch [19595], val_loss: 0.0889
# Epoch [19596], val_loss: 0.0889
# Epoch [19597], val_loss: 0.0889
# Epoch [19598], val_loss: 0.0889
# Epoch [19599], val_loss: 0.0889
# Epoch [19600], val_loss: 0.0889
# Epoch [19601], val_loss: 0.0889
# Epoch [19602], val_loss: 0.0889
# Epoch [19603], val_loss: 0.0889
# Epoch [19604], val_loss: 0.0889
# Epoch [19605], val_loss: 0.0889
# Epoch [19606], val_loss: 0.0889
# Epoch [19607], val_loss: 0.0889
# Epoch [19608], val_loss: 0.0889
# Epoch [19609], val_loss: 0.0889
# Epoch [19610], val_loss: 0.0889
# Epoch [19611], val_loss: 0.0889
# Epoch [19612], val_loss: 0.0889
# Epoch [19613], val_loss: 0.0889
# Epoch [19614], val_loss: 0.0889
# Epoch [19615], val_loss: 0.0889
# Epoch [19616], val_loss: 0.0889
# Epoch [19617], val_loss: 0.0889
# Epoch [19618], val_loss: 0.0889
# Epoch [19619], val_loss: 0.0889
# Epoch [19620], val_loss: 0.0889
# Epoch [19621], val_loss: 0.0889
# Epoch [19622], val_loss: 0.0889
# Epoch [19623], val_loss: 0.0889
# Epoch [19624], val_loss: 0.0889
# Epoch [19625], val_loss: 0.0889
# Epoch [19626], val_loss: 0.0889
# Epoch [19627], val_loss: 0.0889
# Epoch [19628], val_loss: 0.0889
# Epoch [19629], val_loss: 0.0889
# Epoch [19630], val_loss: 0.0889
# Epoch [19631], val_loss: 0.0889
# Epoch [19632], val_loss: 0.0889
# Epoch [19633], val_loss: 0.0889
# Epoch [19634], val_loss: 0.0889
# Epoch [19635], val_loss: 0.0889
# Epoch [19636], val_loss: 0.0889
# Epoch [19637], val_loss: 0.0889
# Epoch [19638], val_loss: 0.0889
# Epoch [19639], val_loss: 0.0889
# Epoch [19640], val_loss: 0.0889
# Epoch [19641], val_loss: 0.0889
# Epoch [19642], val_loss: 0.0889
# Epoch [19643], val_loss: 0.0889
# Epoch [19644], val_loss: 0.0889
# Epoch [19645], val_loss: 0.0889
# Epoch [19646], val_loss: 0.0889
# Epoch [19647], val_loss: 0.0889
# Epoch [19648], val_loss: 0.0889
# Epoch [19649], val_loss: 0.0889
# Epoch [19650], val_loss: 0.0889
# Epoch [19651], val_loss: 0.0889
# Epoch [19652], val_loss: 0.0889
# Epoch [19653], val_loss: 0.0889
# Epoch [19654], val_loss: 0.0889
# Epoch [19655], val_loss: 0.0889
# Epoch [19656], val_loss: 0.0889
# Epoch [19657], val_loss: 0.0889
# Epoch [19658], val_loss: 0.0889
# Epoch [19659], val_loss: 0.0889
# Epoch [19660], val_loss: 0.0889
# Epoch [19661], val_loss: 0.0889
# Epoch [19662], val_loss: 0.0889
# Epoch [19663], val_loss: 0.0889
# Epoch [19664], val_loss: 0.0889
# Epoch [19665], val_loss: 0.0889
# Epoch [19666], val_loss: 0.0889
# Epoch [19667], val_loss: 0.0889
# Epoch [19668], val_loss: 0.0889
# Epoch [19669], val_loss: 0.0889
# Epoch [19670], val_loss: 0.0889
# Epoch [19671], val_loss: 0.0889
# Epoch [19672], val_loss: 0.0889
# Epoch [19673], val_loss: 0.0889
# Epoch [19674], val_loss: 0.0889
# Epoch [19675], val_loss: 0.0889
# Epoch [19676], val_loss: 0.0889
# Epoch [19677], val_loss: 0.0889
# Epoch [19678], val_loss: 0.0889
# Epoch [19679], val_loss: 0.0889
# Epoch [19680], val_loss: 0.0889
# Epoch [19681], val_loss: 0.0889
# Epoch [19682], val_loss: 0.0889
# Epoch [19683], val_loss: 0.0889
# Epoch [19684], val_loss: 0.0889
# Epoch [19685], val_loss: 0.0889
# Epoch [19686], val_loss: 0.0889
# Epoch [19687], val_loss: 0.0889
# Epoch [19688], val_loss: 0.0889
# Epoch [19689], val_loss: 0.0889
# Epoch [19690], val_loss: 0.0889
# Epoch [19691], val_loss: 0.0889
# Epoch [19692], val_loss: 0.0889
# Epoch [19693], val_loss: 0.0889
# Epoch [19694], val_loss: 0.0889
# Epoch [19695], val_loss: 0.0889
# Epoch [19696], val_loss: 0.0889
# Epoch [19697], val_loss: 0.0889
# Epoch [19698], val_loss: 0.0889
# Epoch [19699], val_loss: 0.0889
# Epoch [19700], val_loss: 0.0889
# Epoch [19701], val_loss: 0.0889
# Epoch [19702], val_loss: 0.0889
# Epoch [19703], val_loss: 0.0889
# Epoch [19704], val_loss: 0.0889
# Epoch [19705], val_loss: 0.0889
# Epoch [19706], val_loss: 0.0889
# Epoch [19707], val_loss: 0.0889
# Epoch [19708], val_loss: 0.0889
# Epoch [19709], val_loss: 0.0889
# Epoch [19710], val_loss: 0.0889
# Epoch [19711], val_loss: 0.0889
# Epoch [19712], val_loss: 0.0889
# Epoch [19713], val_loss: 0.0889
# Epoch [19714], val_loss: 0.0889
# Epoch [19715], val_loss: 0.0889
# Epoch [19716], val_loss: 0.0889
# Epoch [19717], val_loss: 0.0889
# Epoch [19718], val_loss: 0.0889
# Epoch [19719], val_loss: 0.0889
# Epoch [19720], val_loss: 0.0889
# Epoch [19721], val_loss: 0.0889
# Epoch [19722], val_loss: 0.0889
# Epoch [19723], val_loss: 0.0889
# Epoch [19724], val_loss: 0.0889
# Epoch [19725], val_loss: 0.0889
# Epoch [19726], val_loss: 0.0889
# Epoch [19727], val_loss: 0.0889
# Epoch [19728], val_loss: 0.0889
# Epoch [19729], val_loss: 0.0889
# Epoch [19730], val_loss: 0.0889
# Epoch [19731], val_loss: 0.0889
# Epoch [19732], val_loss: 0.0889
# Epoch [19733], val_loss: 0.0889
# Epoch [19734], val_loss: 0.0889
# Epoch [19735], val_loss: 0.0889
# Epoch [19736], val_loss: 0.0889
# Epoch [19737], val_loss: 0.0889
# Epoch [19738], val_loss: 0.0889
# Epoch [19739], val_loss: 0.0889
# Epoch [19740], val_loss: 0.0889
# Epoch [19741], val_loss: 0.0889
# Epoch [19742], val_loss: 0.0889
# Epoch [19743], val_loss: 0.0889
# Epoch [19744], val_loss: 0.0889
# Epoch [19745], val_loss: 0.0889
# Epoch [19746], val_loss: 0.0889
# Epoch [19747], val_loss: 0.0889
# Epoch [19748], val_loss: 0.0889
# Epoch [19749], val_loss: 0.0889
# Epoch [19750], val_loss: 0.0889
# Epoch [19751], val_loss: 0.0889
# Epoch [19752], val_loss: 0.0889
# Epoch [19753], val_loss: 0.0889
# Epoch [19754], val_loss: 0.0889
# Epoch [19755], val_loss: 0.0889
# Epoch [19756], val_loss: 0.0889
# Epoch [19757], val_loss: 0.0889
# Epoch [19758], val_loss: 0.0889
# Epoch [19759], val_loss: 0.0889
# Epoch [19760], val_loss: 0.0889
# Epoch [19761], val_loss: 0.0889
# Epoch [19762], val_loss: 0.0889
# Epoch [19763], val_loss: 0.0889
# Epoch [19764], val_loss: 0.0889
# Epoch [19765], val_loss: 0.0889
# Epoch [19766], val_loss: 0.0889
# Epoch [19767], val_loss: 0.0889
# Epoch [19768], val_loss: 0.0889
# Epoch [19769], val_loss: 0.0889
# Epoch [19770], val_loss: 0.0889
# Epoch [19771], val_loss: 0.0889
# Epoch [19772], val_loss: 0.0889
# Epoch [19773], val_loss: 0.0889
# Epoch [19774], val_loss: 0.0889
# Epoch [19775], val_loss: 0.0889
# Epoch [19776], val_loss: 0.0889
# Epoch [19777], val_loss: 0.0889
# Epoch [19778], val_loss: 0.0889
# Epoch [19779], val_loss: 0.0889
# Epoch [19780], val_loss: 0.0889
# Epoch [19781], val_loss: 0.0889
# Epoch [19782], val_loss: 0.0889
# Epoch [19783], val_loss: 0.0889
# Epoch [19784], val_loss: 0.0889
# Epoch [19785], val_loss: 0.0889
# Epoch [19786], val_loss: 0.0889
# Epoch [19787], val_loss: 0.0889
# Epoch [19788], val_loss: 0.0889
# Epoch [19789], val_loss: 0.0889
# Epoch [19790], val_loss: 0.0889
# Epoch [19791], val_loss: 0.0889
# Epoch [19792], val_loss: 0.0889
# Epoch [19793], val_loss: 0.0889
# Epoch [19794], val_loss: 0.0889
# Epoch [19795], val_loss: 0.0889
# Epoch [19796], val_loss: 0.0889
# Epoch [19797], val_loss: 0.0889
# Epoch [19798], val_loss: 0.0889
# Epoch [19799], val_loss: 0.0889
# Epoch [19800], val_loss: 0.0889
# Epoch [19801], val_loss: 0.0889
# Epoch [19802], val_loss: 0.0889
# Epoch [19803], val_loss: 0.0889
# Epoch [19804], val_loss: 0.0889
# Epoch [19805], val_loss: 0.0889
# Epoch [19806], val_loss: 0.0889
# Epoch [19807], val_loss: 0.0889
# Epoch [19808], val_loss: 0.0889
# Epoch [19809], val_loss: 0.0889
# Epoch [19810], val_loss: 0.0889
# Epoch [19811], val_loss: 0.0889
# Epoch [19812], val_loss: 0.0889
# Epoch [19813], val_loss: 0.0889
# Epoch [19814], val_loss: 0.0889
# Epoch [19815], val_loss: 0.0889
# Epoch [19816], val_loss: 0.0889
# Epoch [19817], val_loss: 0.0889
# Epoch [19818], val_loss: 0.0889
# Epoch [19819], val_loss: 0.0889
# Epoch [19820], val_loss: 0.0889
# Epoch [19821], val_loss: 0.0889
# Epoch [19822], val_loss: 0.0889
# Epoch [19823], val_loss: 0.0889
# Epoch [19824], val_loss: 0.0889
# Epoch [19825], val_loss: 0.0889
# Epoch [19826], val_loss: 0.0889
# Epoch [19827], val_loss: 0.0889
# Epoch [19828], val_loss: 0.0889
# Epoch [19829], val_loss: 0.0889
# Epoch [19830], val_loss: 0.0889
# Epoch [19831], val_loss: 0.0889
# Epoch [19832], val_loss: 0.0889
# Epoch [19833], val_loss: 0.0889
# Epoch [19834], val_loss: 0.0889
# Epoch [19835], val_loss: 0.0889
# Epoch [19836], val_loss: 0.0889
# Epoch [19837], val_loss: 0.0889
# Epoch [19838], val_loss: 0.0889
# Epoch [19839], val_loss: 0.0889
# Epoch [19840], val_loss: 0.0889
# Epoch [19841], val_loss: 0.0889
# Epoch [19842], val_loss: 0.0889
# Epoch [19843], val_loss: 0.0889
# Epoch [19844], val_loss: 0.0889
# Epoch [19845], val_loss: 0.0889
# Epoch [19846], val_loss: 0.0889
# Epoch [19847], val_loss: 0.0889
# Epoch [19848], val_loss: 0.0889
# Epoch [19849], val_loss: 0.0889
# Epoch [19850], val_loss: 0.0889
# Epoch [19851], val_loss: 0.0889
# Epoch [19852], val_loss: 0.0889
# Epoch [19853], val_loss: 0.0889
# Epoch [19854], val_loss: 0.0889
# Epoch [19855], val_loss: 0.0889
# Epoch [19856], val_loss: 0.0889
# Epoch [19857], val_loss: 0.0889
# Epoch [19858], val_loss: 0.0889
# Epoch [19859], val_loss: 0.0889
# Epoch [19860], val_loss: 0.0889
# Epoch [19861], val_loss: 0.0889
# Epoch [19862], val_loss: 0.0889
# Epoch [19863], val_loss: 0.0889
# Epoch [19864], val_loss: 0.0889
# Epoch [19865], val_loss: 0.0889
# Epoch [19866], val_loss: 0.0889
# Epoch [19867], val_loss: 0.0889
# Epoch [19868], val_loss: 0.0889
# Epoch [19869], val_loss: 0.0889
# Epoch [19870], val_loss: 0.0889
# Epoch [19871], val_loss: 0.0889
# Epoch [19872], val_loss: 0.0889
# Epoch [19873], val_loss: 0.0889
# Epoch [19874], val_loss: 0.0889
# Epoch [19875], val_loss: 0.0889
# Epoch [19876], val_loss: 0.0889
# Epoch [19877], val_loss: 0.0889
# Epoch [19878], val_loss: 0.0889
# Epoch [19879], val_loss: 0.0889
# Epoch [19880], val_loss: 0.0889
# Epoch [19881], val_loss: 0.0889
# Epoch [19882], val_loss: 0.0889
# Epoch [19883], val_loss: 0.0889
# Epoch [19884], val_loss: 0.0889
# Epoch [19885], val_loss: 0.0889
# Epoch [19886], val_loss: 0.0889
# Epoch [19887], val_loss: 0.0889
# Epoch [19888], val_loss: 0.0889
# Epoch [19889], val_loss: 0.0889
# Epoch [19890], val_loss: 0.0889
# Epoch [19891], val_loss: 0.0889
# Epoch [19892], val_loss: 0.0889
# Epoch [19893], val_loss: 0.0889
# Epoch [19894], val_loss: 0.0889
# Epoch [19895], val_loss: 0.0889
# Epoch [19896], val_loss: 0.0889
# Epoch [19897], val_loss: 0.0889
# Epoch [19898], val_loss: 0.0889
# Epoch [19899], val_loss: 0.0889
# Epoch [19900], val_loss: 0.0889
# Epoch [19901], val_loss: 0.0889
# Epoch [19902], val_loss: 0.0889
# Epoch [19903], val_loss: 0.0889
# Epoch [19904], val_loss: 0.0889
# Epoch [19905], val_loss: 0.0889
# Epoch [19906], val_loss: 0.0889
# Epoch [19907], val_loss: 0.0889
# Epoch [19908], val_loss: 0.0889
# Epoch [19909], val_loss: 0.0889
# Epoch [19910], val_loss: 0.0889
# Epoch [19911], val_loss: 0.0889
# Epoch [19912], val_loss: 0.0889
# Epoch [19913], val_loss: 0.0889
# Epoch [19914], val_loss: 0.0889
# Epoch [19915], val_loss: 0.0889
# Epoch [19916], val_loss: 0.0889
# Epoch [19917], val_loss: 0.0889
# Epoch [19918], val_loss: 0.0889
# Epoch [19919], val_loss: 0.0889
# Epoch [19920], val_loss: 0.0889
# Epoch [19921], val_loss: 0.0889
# Epoch [19922], val_loss: 0.0889
# Epoch [19923], val_loss: 0.0889
# Epoch [19924], val_loss: 0.0889
# Epoch [19925], val_loss: 0.0889
# Epoch [19926], val_loss: 0.0889
# Epoch [19927], val_loss: 0.0889
# Epoch [19928], val_loss: 0.0889
# Epoch [19929], val_loss: 0.0889
# Epoch [19930], val_loss: 0.0889
# Epoch [19931], val_loss: 0.0889
# Epoch [19932], val_loss: 0.0889
# Epoch [19933], val_loss: 0.0889
# Epoch [19934], val_loss: 0.0889
# Epoch [19935], val_loss: 0.0889
# Epoch [19936], val_loss: 0.0889
# Epoch [19937], val_loss: 0.0889
# Epoch [19938], val_loss: 0.0889
# Epoch [19939], val_loss: 0.0889
# Epoch [19940], val_loss: 0.0889
# Epoch [19941], val_loss: 0.0889
# Epoch [19942], val_loss: 0.0889
# Epoch [19943], val_loss: 0.0889
# Epoch [19944], val_loss: 0.0889
# Epoch [19945], val_loss: 0.0889
# Epoch [19946], val_loss: 0.0889
# Epoch [19947], val_loss: 0.0889
# Epoch [19948], val_loss: 0.0889
# Epoch [19949], val_loss: 0.0889
# Epoch [19950], val_loss: 0.0889
# Epoch [19951], val_loss: 0.0889
# Epoch [19952], val_loss: 0.0889
# Epoch [19953], val_loss: 0.0889
# Epoch [19954], val_loss: 0.0889
# Epoch [19955], val_loss: 0.0889
# Epoch [19956], val_loss: 0.0889
# Epoch [19957], val_loss: 0.0889
# Epoch [19958], val_loss: 0.0889
# Epoch [19959], val_loss: 0.0889
# Epoch [19960], val_loss: 0.0889
# Epoch [19961], val_loss: 0.0889
# Epoch [19962], val_loss: 0.0889
# Epoch [19963], val_loss: 0.0889
# Epoch [19964], val_loss: 0.0889
# Epoch [19965], val_loss: 0.0889
# Epoch [19966], val_loss: 0.0889
# Epoch [19967], val_loss: 0.0889
# Epoch [19968], val_loss: 0.0889
# Epoch [19969], val_loss: 0.0889
# Epoch [19970], val_loss: 0.0889
# Epoch [19971], val_loss: 0.0889
# Epoch [19972], val_loss: 0.0889
# Epoch [19973], val_loss: 0.0889
# Epoch [19974], val_loss: 0.0889
# Epoch [19975], val_loss: 0.0889
# Epoch [19976], val_loss: 0.0889
# Epoch [19977], val_loss: 0.0889
# Epoch [19978], val_loss: 0.0889
# Epoch [19979], val_loss: 0.0889
# Epoch [19980], val_loss: 0.0889
# Epoch [19981], val_loss: 0.0889
# Epoch [19982], val_loss: 0.0889
# Epoch [19983], val_loss: 0.0889
# Epoch [19984], val_loss: 0.0889
# Epoch [19985], val_loss: 0.0889
# Epoch [19986], val_loss: 0.0889
# Epoch [19987], val_loss: 0.0889
# Epoch [19988], val_loss: 0.0889
# Epoch [19989], val_loss: 0.0889
# Epoch [19990], val_loss: 0.0889
# Epoch [19991], val_loss: 0.0889
# Epoch [19992], val_loss: 0.0889
# Epoch [19993], val_loss: 0.0889
# Epoch [19994], val_loss: 0.0889
# Epoch [19995], val_loss: 0.0889
# Epoch [19996], val_loss: 0.0889
# Epoch [19997], val_loss: 0.0889
# Epoch [19998], val_loss: 0.0889
# Epoch [19999], val_loss: 0.0889

# %%
losses = [x['val_loss'] for x in history]
plt.plot(losses, '-x')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.title('Loss vs. No. of epochs');

# %%
torch.save(model0.state_dict(), 'HW_1_1_func1model0_v1.pth')

# %%
#import torch
#model0 = torch.load('./HW_1_1_func1model0.pth')

# %%
import pandas as pd
pd.DataFrame(losses).to_csv('HW_1_1_func1model0_v1_losses.csv',index=False)
